# %% [markdown]
# <a href="https://colab.research.google.com/github/Koppolur/Colab-AI/blob/main/ADK_MAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Welcome to Your ADK Adventure - MultiAgents! 🚀
#
# Welcome back, Agent Architect! This notebook dives into the heart of the Google Agent Development Kit (ADK): orchestrating teams of specialized agents to tackle complex, multi-step problems that a single agent cannot handle alone.
#
# By the end of this session, you will be an expert in advanced agentic workflows:
#
# - **SequentialAgent**: You'll learn to chain agents together, creating pipelines where the output of one agent becomes the input for the next.
#
# - **LoopAgent**: You'll build iterative systems where agents can plan, critique, and refine their work until a specific goal is met, making them "perfectionists."
#
# - **ParallelAgent**: You'll unleash efficiency by running multiple agents simultaneously and then synthesizing their collective findings into a single, comprehensive answer.
#
# - **The Router**: You will construct a "master" router agent that intelligently analyzes a user's request and delegates it to the correct agent or workflow.
#
# Let's get this adventure started!

# %% [markdown]
# ## Author
#
# HI, I'm Qingyue (Annie) Wang, a developer advocate and AI engineer at **Google**, passionate about helping developers build with AI and cloud technologies :)
#
#
# If you have questions with this notebook, contact me on [LinkedIn](https://www.linkedin.com/in/anniewangtech/) , [X](https://twitter.com/anniewangtech) or email anniewangtech0510@Gmail.com
#
#
# ```
#
#   (\__/)
#   (•ㅅ•)
#   /づ  📚       Enjoy learning AI Agents :)
#
#
# ```

# %% [markdown]
# -------------
# ### 🎁 🛑 Important Prerequisite: Setup Your Environment! 🛑 🎁
# -----------------------------------------------------------------------------
#
# 👉 **Get Your API Key HERE**: https://codelabs.developers.google.com/onramp/instructions#0
#
#  -----------------------------------------------------------------------------

# %% [markdown]
# ```
#  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️
#    /\_/\     /\_/\     /\_/\      /\_/\       /\_/\
#   ( ^_^ )   ( -.- )   ( >_< )   ( =^.^= )    ( o_o )
# ```

# %% [markdown]
# ## Part 0: Setup & Authentication 🔑
#
# First things first, let's get all our tools ready. This step installs the necessary libraries and securely configures your Google API key so your agents can access the power of Gemini.

# %%
# !pip install google-adk google-generativeai -q

# --- Import all necessary libraries for our entire adventure ---
import os
import re
import asyncio
from IPython.display import display, Markdown
import google.generativeai as genai
from google.adk.agents import Agent, SequentialAgent, LoopAgent, ParallelAgent
from google.adk.tools import google_search, ToolContext
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService, Session
from google.genai.types import Content, Part
from getpass import getpass

print("✅ All libraries are ready to go!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.3/239.3 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.1/218.1 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.7/335.7 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.5/158.5 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.5/229.5 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.4 which is incompatible.
# ✅ All libraries are ready to go!

# %%
# --- Securely Configure Your API Key ---

# Prompt the user for their API key securely
api_key = ('AIzaSyAVrm0Ec_5sd8S9Z5NP7S5cQPORWwFIbrM')

# Get Your API Key HERE 👉 https://codelabs.developers.google.com/onramp/instructions#0
# Configure the generative AI library with the provided key
genai.configure(api_key=api_key)

# Set the API key as an environment variable for ADK to use
os.environ['GOOGLE_API_KEY'] = api_key

print("✅ API Key configured successfully! Let the fun begin.")
# Out:
# ✅ API Key configured successfully! Let the fun begin.

# %%
# --- A Helper Function to Run Our Agents ---
# We'll use this function throughout the notebook to make running queries easy.

async def run_agent_query(agent: Agent, query: str, session: Session, user_id: str, is_router: bool = False):
    """Initializes a runner and executes a query for a given agent and session."""
    print(f"\n🚀 Running query for agent: '{agent.name}' in session: '{session.id}'...")

    runner = Runner(
        agent=agent,
        session_service=session_service,
        app_name=agent.name
    )

    final_response = ""
    try:
        async for event in runner.run_async(
            user_id=user_id,
            session_id=session.id,
            new_message=Content(parts=[Part(text=query)], role="user")
        ):
            if not is_router:
                # Let's see what the agent is thinking!
                print(f"EVENT: {event}")
            if event.is_final_response():
                final_response = event.content.parts[0].text
    except Exception as e:
        final_response = f"An error occurred: {e}"

    if not is_router:
     print("\n" + "-"*50)
     print("✅ Final Response:")
     display(Markdown(final_response))
     print("-"*50 + "\n")

    return final_response

# --- Initialize our Session Service ---
# This one service will manage all the different sessions in our notebook.
session_service = InMemorySessionService()
my_user_id = "adk_adventurer_001"

# %% [markdown]
# ---
# ## Part 1: Multi-Agent Mayhem - Sequential Workflows 🧠→🤖→🤖
#
# Some tasks are too complex for one agent. A user might ask, "Find me a great restaurant and then tell me how to get there." This requires two different skills: food recommendation and navigation.

# %% [markdown]
# ```
# +----------------+     +------------------------+
# | foodie_agent 🍣 |    | transportation_agent 🚗 |
# | Finds place     | -->| Uses {destination}     |
# | Output: 'Jin Sho'|   | Output: Directions     |
# +----------------+     +------------------------+
# ```

# %%
# --- Agent Definitions for our Specialist Team ---
# --- Agent Definition ---

foodie_agent = Agent(
    name="foodie_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are an expert food critic. Your goal is to find the absolute best food, restaurants, or culinary experiences based on a user's request. When you recommend a place, state its name clearly. For example: 'The best sushi is at **Jin Sho**.'"
)


transportation_agent = Agent(
    name="transportation_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are a navigation assistant. Given a starting point and a destination, provide clear directions on how to get from the start to the end."
)

# %%
# The "Hard Way" - Corrected to Print the Final Output
async def run_manual_app():
    query = "Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station."

    # 1. Run the first agent
    print("➡️ Running foodie_agent to find the destination...")
    foodie_session = await session_service.create_session(app_name=foodie_agent.name, user_id=my_user_id)
    foodie_response = await run_agent_query(foodie_agent, query, foodie_session, my_user_id)

    # 2. Manually parse the output
    print("...parsing response to find the name...")
    match = re.search(r'\*\*(.*?)\*\*', foodie_response)
    if not match:
        print("🚨 Could not determine the restaurant name.")
        return # Exit if parsing fails
    destination = match.group(1)
    print(f"💡 Destination found: {destination}")

    # 3. Manually create a new query for the next agent
    directions_query = f"Give me directions to {destination} from the Palo Alto Caltrain station."
    print(f"➡️ Running transportation_agent with new query: '{directions_query}'")

    # 4. Run the second agent with the new query
    transport_session = await session_service.create_session(app_name=transportation_agent.name, user_id=my_user_id)

    # --- ✨ CORRECTION HERE ---
    # 5. Run the second agent and CAPTURE the final output
    final_directions = await run_agent_query(transportation_agent, directions_query, transport_session, my_user_id)

    # 6. Print the final output
    print("\n--- ✅ Final Response from Manual Workflow ---")
    print(final_directions)
    print("-----------------------------------------")

await run_manual_app()
# Out:
# ➡️ Running foodie_agent to find the destination...
#
# 🚀 Running query for agent: 'foodie_agent' in session: 'caebdf42-694b-4a9e-add9-4f33edd292a3'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""When it comes to the best sushi in Palo Alto, several establishments consistently receive high praise for their quality and experience.
#
# One of the top recommendations is **Jin Sho**. It's frequently cited as a favorite for its fresh sushi, including highly praised otoro and creamy uni. Jin Sho is also noted for being the late Steve Jobs' favorite restaurant and offers great sushi, though portions can be small and prices expensive. They are known for exquisite Japanese cuisine and have chefs who previously worked at Nobu in New York. Jin Sho is located at 454 California Ave., Palo Alto.
#
# Another highly regarded option is **Iki Omakase Palo Alto**, offering a modern and refined omakase experience from Chef Jb Li, who previously honed his skills at prestigious sushi establishments in San Francisco. They focus on using the finest globally and locally sourced ingredients.
#
# **Fuki Sushi** is a long-standing Palo Alto establishment often mentioned for its consistent high quality, warm atmosphere, and private seating. While some reviews suggest it might be slightly overrated by those less familiar with sushi, it's still considered a strong contender.
#
# For a more upscale and inventive experience, **Sushi Roku - Palo Alto** at Stanford Shopping Center offers "excellent service" and "delicious sushi" with inventive rolls and appetizers, though it's on the pricier side.
#
# **Araki Sushi** on University Ave is praised for its authentic Japanese dining, masterful sushi craftsmanship, and fresh ingredients, offering a "symphony of textures."
#
# Here's how to get to **Jin Sho** from the Caltrain station in Palo Alto:
#
# **Jin Sho** is located at 454 California Ave, Palo Alto, CA. The Caltrain station in Palo Alto is located at 95 University Ave, Palo Alto, CA.
#
# **Walking (approximately 15-20 minutes):**
#
# 1.  From the Caltrain station, head southeast on University Ave toward El Camino Real.
# 2.  Turn right onto El Camino Real.
# 3.  Turn left onto California Ave. Jin Sho will be on your left.
#
# **Public Transportation (SamTrans Bus - approximately 10-15 minutes including wait time):**
#
# 1.  From the Caltrain station, walk to the bus stop on University Ave @ Caltrain Station.
# 2.  Take SamTrans bus route 22 (Southbound towards Menlo Park/San Jose Diridon) or 397 (Southbound towards San Jose Diridon).
# 3.  Exit at California Ave & El Camino Real.
# 4.  Walk a short distance down California Ave to reach Jin Sho.
#
# **Taxi/Rideshare (approximately 5-7 minutes):**
#
# A taxi or rideshare service would be the quickest option and readily available from the Caltrain station, dropping you directly at Jin Sho."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='wanderlog.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHDm578dqfrevRUSHfDOgmrjhnJwY0e16NwEHs_NYcfgsTJWtcvZwJ02ffzpKCScSXZx7-59caGLtjAzef8nWHwU4HR78SsWicq8D-1-M1a4W2usoYWW5JT2xcLZQMGX1JcW4sFBv6gKcUJaGDEJ4Zdr3xe89eEaoI8N_Aj6Cv5k_JRkhZD7hnuBKCkZeSnVP7Hais4JjnFvIES8g=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='reddit.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFYo-P0hnqiJBWcsHr2f1xghlHq1SCMrzenLNLi3UY5KHIuQXTeL1TAlaZRonvW_rQVYiJSnLsyieCHn8xuOFPsWHdDEIYRqNDaOxW2o2XXEfAvSXYRLFEi_RXETPRD6haaI5OxtxSWjJmiLuuxX17vd2XM2FtiGVcMQJMznD_kRRKVpbj3TBLq6TILBDkoQYKQttFx6Prmy4Is86uqxaly'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='stanforddaily.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFmaS-dpao9LQktsJ4vnd1MnGHWJqA1B1N080f_KE_WVdymSLRvD7olrE-E4yqSAVi2it7WgdNxBiIhPQ5H9RNe48BZfN8NxoeEkDWDChePAj_UW1Yuk9rGsAGijmX-sPNe2TGzSvMQ8iiC_nv0twGhBBlPxRH7KTIaLZm2OZGd6wkCIuKP'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='modernluxury.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHqShvxmm2Z-Dw_Qtu12IzaPCIlwniGa7-1k-guZmKtM125l2UN4_qU5WNm2PHXn6WtFvZ7XUyUY5y5_sTcujNCmJOsw_CPLOKLjqU_9mttW3nwDOzdVYpErvIJ6zIJ_BfPx0Vfloz8fqymty_yowNmjQs='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='ikiomakasepaloalto.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFCsQOwBUrDfo6TMqEuk_hs6RVgHVa6biinXATCuQ7jR5sXKe3ewMuP5qzvI5C5UWqvLyH7_or6ufycWsvEphLqtclNGtzutuc4wZCCpkHxmN04KKjx8tYEBGRnuurc'
#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=287,
#         start_index=184,
#         text="It's frequently cited as a favorite for its fresh sushi, including highly praised otoro and creamy uni."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=435,
#         start_index=288,
#         text="Jin Sho is also noted for being the late Steve Jobs' favorite restaurant and offers great sushi, though portions can be small and prices expensive."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=539,
#         start_index=436,
#         text='They are known for exquisite Japanese cuisine and have chefs who previously worked at Nobu in New York.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=593,
#         start_index=540,
#         text='Jin Sho is located at 454 California Ave., Palo Alto.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#       ],
#       segment=Segment(
#         end_index=807,
#         start_index=595,
#         text='Another highly regarded option is **Iki Omakase Palo Alto**, offering a modern and refined omakase experience from Chef Jb Li, who previously honed his skills at prestigious sushi establishments in San Francisco.'
#       )
#     ),
#     <... 6 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG_KDTmej6AIVlXC6vhryCq3jRY19yU7xJuWSH6wUs5Lxm8FlbzSQuRWKweKPrpJASuGqPMzAWQJphkx4iysuTsZqOp7NEa8DHd_EepAKxNUA-A9R6pubMLmnRqj9xkBkt4y3Ad6d8m7K4fiXVoZcUFDMkz2vKTP9kkfUUNZ3gZrrWvDk0ey97mXIZAiSljepE9ycWtOZv1Aw_Ma7Yk">best rated sushi Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGcxf7-KhwpCJ_ePkRtd0IffqVA1NMiNkOjyTcH71s3VrS7PgBVxXOlBgg-84GErAmD0faHK2SYboWXOrEjHuVsJOlUzxym-EPoBZqCCAhCPzr4ijqBmyus1V2GrQ2jkcTb1lZ5hMqIXmNsoS734Vq8gC1IQlVtkPbLBhkbHjCM-Jiq2mVNmCTBJeWfDbemO5Pfwzhwrbrg4Sol">best sushi in Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEFCqsdZdKvvQMnYBDwBJyhR23lBhPD_K7tTt6zyMF44ofr8Z3m29qauApb6VLy0Yr5R8c25zQnp_0qHWJwBSxUP9CZ1QVtlu9MH7ore1n0Ld7rvxOvP3JOvKOEBYra0J8f5qGNjLhvF-9kcKYJoXF8wKb6wy4ZkKPciG1L4mJWq6Txg7tEa7f8aX-9dtG3XKhuA0vzQfrjcPy47g==">high-end sushi Palo Alto</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi in Palo Alto',
#     'best rated sushi Palo Alto',
#     'high-end sushi Palo Alto',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=620,
#   prompt_token_count=95,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=95
#     ),
#   ],
#   thoughts_token_count=69,
#   total_token_count=784
# ) invocation_id='e-8f98372a-25ec-4f36-a9fe-05f0348832c0' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='b36f8d5a-8fe7-4c88-8cc6-ab6ac7901c03' timestamp=1753979398.268864
#
# --------------------------------------------------
# ✅ Final Response:
# When it comes to the best sushi in Palo Alto, several establishments consistently receive high praise for their quality and experience.
#
# One of the top recommendations is **Jin Sho**. It's frequently cited as a favorite for its fresh sushi, including highly praised otoro and creamy uni. Jin Sho is also noted for being the late Steve Jobs' favorite restaurant and offers great sushi, though portions can be small and prices expensive. They are known for exquisite Japanese cuisine and have chefs who previously worked at Nobu in New York. Jin Sho is located at 454 California Ave., Palo Alto.
#
# Another highly regarded option is **Iki Omakase Palo Alto**, offering a modern and refined omakase experience from Chef Jb Li, who previously honed his skills at prestigious sushi establishments in San Francisco. They focus on using the finest globally and locally sourced ingredients.
#
# **Fuki Sushi** is a long-standing Palo Alto establishment often mentioned for its consistent high quality, warm atmosphere, and private seating. While some reviews suggest it might be slightly overrated by those less familiar with sushi, it's still considered a strong contender.
#
# For a more upscale and inventive experience, **Sushi Roku - Palo Alto** at Stanford Shopping Center offers "excellent service" and "delicious sushi" with inventive rolls and appetizers, though it's on the pricier side.
#
# **Araki Sushi** on University Ave is praised for its authentic Japanese dining, masterful sushi craftsmanship, and fresh ingredients, offering a "symphony of textures."
#
# Here's how to get to **Jin Sho** from the Caltrain station in Palo Alto:
#
# **Jin Sho** is located at 454 California Ave, Palo Alto, CA. The Caltrain station in Palo Alto is located at 95 University Ave, Palo Alto, CA.
#
# **Walking (approximately 15-20 minutes):**
#
# 1.  From the Caltrain station, head southeast on University Ave toward El Camino Real.
# 2.  Turn right onto El Camino Real.
# 3.  Turn left onto California Ave. Jin Sho will be on your left.
#
# **Public Transportation (SamTrans Bus - approximately 10-15 minutes including wait time):**
#
# 1.  From the Caltrain station, walk to the bus stop on University Ave @ Caltrain Station.
# 2.  Take SamTrans bus route 22 (Southbound towards Menlo Park/San Jose Diridon) or 397 (Southbound towards San Jose Diridon).
# 3.  Exit at California Ave & El Camino Real.
# 4.  Walk a short distance down California Ave to reach Jin Sho.
#
# **Taxi/Rideshare (approximately 5-7 minutes):**
#
# A taxi or rideshare service would be the quickest option and readily available from the Caltrain station, dropping you directly at Jin Sho.
# --------------------------------------------------
#
# ...parsing response to find the name...
# 💡 Destination found: Jin Sho
# ➡️ Running transportation_agent with new query: 'Give me directions to Jin Sho from the Palo Alto Caltrain station.'
#
# 🚀 Running query for agent: 'transportation_agent' in session: '34e3cfc2-a1d7-4568-9c20-64bb3cc790ef'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Jin Sho is located at 454 S California Ave, Palo Alto, CA 94306.
#
# Here are the directions to Jin Sho from the Palo Alto Caltrain station:
#
# **Walking Directions (approximately 15-20 minutes):**
#
# 1.  From the Palo Alto Caltrain station, head southeast on University Ave toward Alma St.
# 2.  Turn right onto Alma St.
# 3.  Turn left onto California Ave.
# 4.  Continue on California Ave, and Jin Sho will be on your right at 454 California Ave.
#
# **Driving/Ride-share Directions (approximately 5-10 minutes, depending on traffic):**
#
# 1.  From the Palo Alto Caltrain station, head southeast on University Ave toward Alma St.
# 2.  Turn right onto Alma St.
# 3.  Turn left onto California Ave.
# 4.  Continue on California Ave, and Jin Sho will be on your right at 454 California Ave.
#
# There is a public lot available for parking near Jin Sho."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='opentable.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEpJT7WVQT7IEgHRuRJ8byzwMwxKpH7EvqrSj4g3lLobCQxLt7tQRl7NZfhquOProsSJQn-5uMYPHXX_-wmDYLXLnqGvU1oYvObIstwm11_mjrXEnw1DvOhWf7ChfS1OaLdWhaGvRul8g=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='doordash.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFAPMWI2Xk_HQjPdbn7EPjQ1MIXP0JO9tOFXMAcd-587Vfrgp2l2f1TXd7sRn2XNuWQ8N0VPLV6Ea_UDeJwZ4O7DIQudeL9yIu5B_9SUqAerzCxGTTpP38c7f4WAVKdQeUFj34-PjsFN8ZY8oCIY43WxSTeiZd7'
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=64,
#         text='Jin Sho is located at 454 S California Ave, Palo Alto, CA 94306.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=826,
#         start_index=769,
#         text='There is a public lot available for parking near Jin Sho.'
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGNK09xtFA69gzG_fbvrylDpIDQbvE61ShTIKc8DUOjjlb2SHYtVGzxkHNITbaJfCxmWKjfBlRS3KR6Izk4pUxdakGtBCbz9nq9QzfNnzDbpdCkqoxXS5yzzGinJWRfx5N5OiBj6l0KOu9kWmn69Xm9DgL_6Lz0RB9zPKpysIr_kb9mFpv8oQTOzysBnFFtYHJ8mHl1HbkTz1zgDFc=">Jin Sho address Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGxeaRMQafQ0GMOBuqOqeSMhMnMxElQju1H7hFLNMU97tiATKu7FXOk_QfBZlHbhBJdmNiGPxnfc3v9-PANsxUKSkKcB2SC1IxTMQ9sBW-_cr9rmxu0Z31A8j896E5ZMsmYYjz_1TX-7uNIuWHaNfkPsDXTzwTpVoclCHty10dr-_0nwJKnMbs0JTnnoAegrTDsOU9dbnPmjBZB4xLJVmbIRG-KbWFEOLlbb-Jox-z4x0EcZssaqRVWLQ==">directions from Palo Alto Caltrain station to Jin Sho</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Jin Sho address Palo Alto',
#     'directions from Palo Alto Caltrain station to Jin Sho',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=250,
#   prompt_token_count=60,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=60
#     ),
#   ],
#   thoughts_token_count=52,
#   total_token_count=362
# ) invocation_id='e-9b9cbd37-54d8-4f8f-9726-ff11eca7fe20' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='7208f24e-0f47-44e9-bb18-2dbde38c656c' timestamp=1753979412.576404
#
# --------------------------------------------------
# ✅ Final Response:
# Jin Sho is located at 454 S California Ave, Palo Alto, CA 94306.
#
# Here are the directions to Jin Sho from the Palo Alto Caltrain station:
#
# **Walking Directions (approximately 15-20 minutes):**
#
# 1.  From the Palo Alto Caltrain station, head southeast on University Ave toward Alma St.
# 2.  Turn right onto Alma St.
# 3.  Turn left onto California Ave.
# 4.  Continue on California Ave, and Jin Sho will be on your right at 454 California Ave.
#
# **Driving/Ride-share Directions (approximately 5-10 minutes, depending on traffic):**
#
# 1.  From the Palo Alto Caltrain station, head southeast on University Ave toward Alma St.
# 2.  Turn right onto Alma St.
# 3.  Turn left onto California Ave.
# 4.  Continue on California Ave, and Jin Sho will be on your right at 454 California Ave.
#
# There is a public lot available for parking near Jin Sho.
# --------------------------------------------------
#
#
# --- ✅ Final Response from Manual Workflow ---
# Jin Sho is located at 454 S California Ave, Palo Alto, CA 94306.
#
# Here are the directions to Jin Sho from the Palo Alto Caltrain station:
#
# **Walking Directions (approximately 15-20 minutes):**
#
# 1.  From the Palo Alto Caltrain station, head southeast on University Ave toward Alma St.
# 2.  Turn right onto Alma St.
# 3.  Turn left onto California Ave.
# 4.  Continue on California Ave, and Jin Sho will be on your right at 454 California Ave.
#
# **Driving/Ride-share Directions (approximately 5-10 minutes, depending on traffic):**
#
# 1.  From the Palo Alto Caltrain station, head southeast on University Ave toward Alma St.
# 2.  Turn right onto Alma St.
# 3.  Turn left onto California Ave.
# 4.  Continue on California Ave, and Jin Sho will be on your right at 454 California Ave.
#
# There is a public lot available for parking near Jin Sho.
# -----------------------------------------

# %% [markdown]
# ---
# ### Part 1 (The ADK Way): Multi-Agent Mayhem with `SequentialAgent` 🧠→⛓️→🤖
#
# You've seen how to manually link agents together with custom Python code. It works, but it can get complicated. Now, let's refactor our workflow to use a powerful, built-in ADK feature designed specifically for this: the **`SequentialAgent`**.
#
# The `SequentialAgent` is a *workflow agent*. It's not powered by an LLM itself; instead, its only job is to execute a list of other agents in a strict, predefined order.
#
# The real magic ✨ is how it passes information. The ADK uses a shared `state` dictionary that each agent in the sequence can read from and write to.
#
# **Our New Workflow:**
#
# 1.  **Foodie Agent**: Finds the restaurant and saves the name to `state['destination']`.
# 2.  **Transportation Agent**: Automatically reads `state['destination']` and uses it to find directions.
#
# This means we no longer need custom Python code to extract text or build new queries! The ADK handles the plumbing for us.

# %% [markdown]
# ```
# +-------------------------------+
# |  find_and_navigate_agent 🧭   |
# | SequentialAgent:             |
# | 1. Find destination          |
# | 2. Get directions            |
# +---------------+---------------+
#                 |
#      +----------+----------+
#      |                     |
#      v                     v
# +----------------+   +------------------------+
# | foodie_agent 🍣 |   | transportation_agent 🚗 |
# | Finds place     |   | Uses {destination}     |
# | Output: 'Jin Sho'|   | Output: Directions     |
# +----------------+   +------------------------+
#
# Final Output: 🍣 Restaurant + 🚗 Route
# ```

# %% [markdown]
# Step 1: Define the Specialist "Worker" Agents
# First, we define our individual specialist agents. The magic lies in two key parameters: output_key and the {placeholder} syntax.
#
# The Information Producer (foodie_agent): This agent's job is to find a piece of information. We'll add an output_key to tell the framework where to save its final answer.
#
# The Information Consumer (transportation_agent): This agent's job is to use the information from the first agent. We'll use a {placeholder} in its instructions that matches the output_key from the producer.

# %% [markdown]
# Now, we define the SequentialAgent. We simply list the worker agents in the exact order we want them to run. The framework handles the rest.

# %%
# --- Agent Definitions for our Specialist Team (Refactored for Sequential Workflow) ---

# Note the new `output_key` and the more specific instruction.
foodie_agent = Agent(
    name="foodie_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are an expert food critic. Your goal is to find the best restaurant based on a user's request.

    When you recommend a place, you must output *only* the name of the establishment and nothing else.
    For example, if the best sushi is at 'Jin Sho', you should output only: Jin Sho
    """,
    output_key="destination"  # ADK will save the agent's final response to state['destination']
)

# The `{destination}` placeholder is automatically filled by the ADK from the state.
transportation_agent = Agent(
    name="transportation_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are a navigation assistant. Given a destination, provide clear directions.
    The user wants to go to: {destination}.

    Analyze the user's full original query to find their starting point.
    Then, provide clear directions from that starting point to {destination}.
    """,
)

# This agent will run foodie_agent, then transportation_agent, in that exact order.
find_and_navigate_agent = SequentialAgent(
    name="find_and_navigate_agent",
    sub_agents=[foodie_agent, transportation_agent],
    description="A workflow that first finds a location and then provides directions to it."
)

# %%
# --- Let's Test the Streamlined Workflow! ---

async def run_sequential_workflow():
    """
    A simplified test function that directly invokes the SequentialAgent.
    """

    # The query contains all the information needed for the entire sequence.
    query = "Find me the best sushi restaurant in Palo Alto, and then tell me how to get there from the downtown Caltrain station."

    print(f"\n{'='*60}\n🗣️  Processing Query: '{query}'\n{'='*60}")
    print(f"🚀 Handing off the entire task to the '{find_and_navigate_agent.name}'...")

    # 1. Create a single session for our sequential agent
    # The session will manage the state (like the 'destination' variable) across the sub-agent calls.
    session = await session_service.create_session(app_name=find_and_navigate_agent.name, user_id=my_user_id)

    # 2. Run the query
    # The SequentialAgent will automatically:
    #   - Call foodie_agent with the query.
    #   - Take its output and save it to the state as `state['destination']`.
    #   - Call transportation_agent, injecting the destination into its prompt.
    #   - Stream the final response from the transportation_agent.
    await run_agent_query(find_and_navigate_agent, query, session, my_user_id)

    print(f"\n--- ✅ '{find_and_navigate_agent.name}' Workflow Complete ---")


# Execute the simplified test
await run_sequential_workflow()
# Out:
# ============================================================
# 🗣️  Processing Query: 'Find me the best sushi restaurant in Palo Alto, and then tell me how to get there from the downtown Caltrain station.'
# ============================================================
# 🚀 Handing off the entire task to the 'find_and_navigate_agent'...
#
# 🚀 Running query for agent: 'find_and_navigate_agent' in session: '68a48c7b-2252-4949-aa29-bd2e8bec74af'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Jin Sho'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHXLX7N64It4bqiikkQp7-pyM-2mm9FrALzB57LwMk5e2O72-SsP5D7VMMAQadmwFnQy210dw1Rq-EdROOPYy7t5TiiNebZk3pugw-VSLrpucwDWjMuM9_h1uz5gmWHhN-twvIhTmIrqxUDy28pD6mVUPtY2FHneJOuNtPygcU9elXnWpDiWLECnfCPn2os9j-kZzGf0uSZBLIpxEThaShnP2iUrBxq4_aNn3rGPCsp-dtu6AnuFLdqoC8tjsDKyiEy4g==">directions from Palo Alto Caltrain Station to Jin Sho Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGsXqzn5Zl1F8ljY_WQFBMqKg29gQeWF85ghK4HvwtKSu6yzAVqYQUkuLPAHiykra8JjsHOCTyO6lPPSQbJevNYIOF92v8RFUDOiwprPKL9a78qysdBewN2u6-wI9IfhC3SSpQXpPRCH4DOku9cFlyfhnqBjwLov_PA_YNp_YIhtAE78zJF6K16lcQuK9RA6DRk0cGmZImxmn9niA==">Jin Sho Palo Alto address</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi restaurant Palo Alto',
#     'How to get to Nobu Palo Alto from downtown Caltrain station',
#     'Jin Sho Palo Alto address',
#     'directions from Palo Alto Caltrain Station to Jin Sho Palo Alto',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=63,
#   prompt_token_count=113,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=113
#     ),
#   ],
#   thoughts_token_count=1536,
#   total_token_count=1712
# ) invocation_id='e-394689dc-17d7-4b41-8626-f56cf8ea0359' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={'destination': 'Jin Sho'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='d1a64010-8270-438c-affe-168874d97971' timestamp=1753979469.660747
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Jin Sho, located at 454 S California Ave, Palo Alto, CA 94306, is a highly-praised Japanese-Asian Fusion sushi bar. It's known for its fresh nigiri, sashimi, and innovative dishes.
#
# To get to Jin Sho from the downtown Caltrain station in Palo Alto (95 University Ave, Palo Alto, CA):
#
# 1.  **Start at Palo Alto Caltrain Station:** The station is located at 95 University Avenue.
# 2.  **Walk South on University Avenue:** Head towards downtown Palo Alto.
# 3.  **Turn Right onto California Avenue:** Jin Sho will be on your right at 454 S California Ave.
#
# The walk should be straightforward and take approximately 10-15 minutes, depending on your pace."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='opentable.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHmkYr6o_oRab4j-iMnZlFsXYO0J1lk-gYuzQAZY8ClZYkwOWznsyM8KsEXdrW_I8yDEU8Uq4QaSobqNRFlWcTJO-THf8U94zBBXRMSsWF57xL4710vivqrMYRmXgNFD-Vv73WdtX_kfg=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='restaurants-world.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFs8McvcUaRXq93XSxQmmxuNBPcU-z8pwGdXnCBttvVpOhpDnXkud3YF46NywLceiAk_gmpwvTrQDI3X9lE3xvdCaA7nbjNF8ocweOpfQ6bV7suKOw4SLthOlNne3-CX6I3arbv8g=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='wheree.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGHpkXhR25KHydVUMiYTQIT3oiPPZEeJItts-UQ-uXkPjpsI5dW_AVmbJz8Ch7WUPfc-R6rTc-OqEDh6kFFGL6hPXgtPv9aQLTI96PutX4faqoBPfJ3ggJYpmfIgXqzYZsLKMasuLMrF5w='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sfbaytransit.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEdcChbftBI-Y44_Mh-dg0wGEUEO2iJqlFtY-fbYfj8XI2hKt51jyGPDhzAxrK6udvkfVHlIOV43q9yA3oQsG57T0LHxaeqdUEjmOSSbEdae2hAyJt7nWHBCHRp3wEg4Ue7ceMzwsysoTNzlQz0cg=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='waze.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHdFP1bO99uryiizP3Z8vlNwGUXz6ErCeAkjoZUjGUSOKo0LlSeiAUEgoon0vCvQbrCJWl7Qyg3ygV-jqnia_34_KWafCaqHzkGI3AamjnqiCX0H0z5hr_6SXVKlCn9b8P9pBFDON0yuEcEe0hTQamXIbl3JZ21zXGTye2L0lM97Qg9MhOY0gpurSzjwM0H-FnVjAch88tEj-_yZdXrezMD'
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=115,
#         text='Jin Sho, located at 454 S California Ave, Palo Alto, CA 94306, is a highly-praised Japanese-Asian Fusion sushi bar.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#       ],
#       segment=Segment(
#         end_index=180,
#         start_index=116,
#         text="It's known for its fresh nigiri, sashimi, and innovative dishes."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#         3,
#       ],
#       segment=Segment(
#         end_index=283,
#         start_index=182,
#         text='To get to Jin Sho from the downtown Caltrain station in Palo Alto (95 University Ave, Palo Alto, CA):'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=377,
#         start_index=289,
#         text='**Start at Palo Alto Caltrain Station:** The station is located at 95 University Avenue.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         4,
#       ],
#       segment=Segment(
#         end_index=549,
#         start_index=456,
#         text='**Turn Right onto California Avenue:** Jin Sho will be on your right at 454 S California Ave.'
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFtHoKw53CI0YcLJyxLrFUfaktvdoA4t7LC9mBWvzc0DgyJUqOFDf1XFc2JYuEKTSUUSN0sMuNrwKp8yFjglyIraSEjuzcsDMrk5BQc5peHWw_ipTFEt2jjNiIzqidpbYBUcarYJzqC04OMofvBE3wqoNhlUd1cwQkCI2qYIZWD-Bev-bUBrTWZIvTORzcTFDLu60JsanM8RTwQ5zHdX2hwFd7KrvFkU4QkuhTttQTr2_G-U5aOuo55-5M=">directions from downtown Palo Alto Caltrain to Jin Sho</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFdD4HL1UOtpAZEqKk3lowWZ-HEtAnXkkD16J4YCocs8uB-yT6rnPtzYrGgIfzi8xUQM_bozWi6kn3DJpkqRW4U1xX83SY4n5pC7BgL2qheTVR3h8iMtotYhDwv3XAlhnu_sFRcrBDmUNM8dgxFpfCbdN2uBmCYHJQyhBL3uMzaeirPPheqgp4WU0LloiSpFmLzu3XoQG57-ZeXS5s=">Jin Sho Palo Alto address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEFdmzKt6xX3451u29dodo5GaPGEUT-PCo-ufMhRkluqjgbNGj_eEUE6V2Enf4PSk_sa1kQqg7RrMz8kwaw7dCl2xVLH5qve40gFb9IgWafYq5OfMRpab3-nwlI0gZKEG2iRj5LK5DXZDPfmrZGrgy16atdnLVlCTrEEVsH6fPK8jTLwk1jvIWA5YT3-wC3tqVg0rVNVzIFJthjqlO6tlY6bGKjM_exDEu0teD-Oow=">downtown Caltrain station Palo Alto address</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Jin Sho Palo Alto address',
#     'downtown Caltrain station Palo Alto address',
#     'directions from downtown Palo Alto Caltrain to Jin Sho',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=207,
#   prompt_token_count=116,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=116
#     ),
#   ],
#   thoughts_token_count=47,
#   total_token_count=370
# ) invocation_id='e-394689dc-17d7-4b41-8626-f56cf8ea0359' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='e920f70f-dc90-44cc-8f70-a286a9f0ea22' timestamp=1753979487.920459
#
# --------------------------------------------------
# ✅ Final Response:
# Jin Sho, located at 454 S California Ave, Palo Alto, CA 94306, is a highly-praised Japanese-Asian Fusion sushi bar. It's known for its fresh nigiri, sashimi, and innovative dishes.
#
# To get to Jin Sho from the downtown Caltrain station in Palo Alto (95 University Ave, Palo Alto, CA):
#
# 1.  **Start at Palo Alto Caltrain Station:** The station is located at 95 University Avenue.
# 2.  **Walk South on University Avenue:** Head towards downtown Palo Alto.
# 3.  **Turn Right onto California Avenue:** Jin Sho will be on your right at 454 S California Ave.
#
# The walk should be straightforward and take approximately 10-15 minutes, depending on your pace.
# --------------------------------------------------
#
#
# --- ✅ 'find_and_navigate_agent' Workflow Complete ---

# %% [markdown]
# ---
# ## Parallel Power with `ParallelAgent` 🧠→⚡️→🤖🤖🤖
#
# What if a user wants to find multiple, unrelated things at once? "Find me a museum, a concert, AND a restaurant." Running these searches one by one is slow and inefficient.
#
# Enter the **`ParallelAgent`**. This workflow agent executes a list of sub-agents *concurrently*, dramatically speeding up tasks that can be performed independently.
#
# **Our New Workflow: The Multi-Researcher**
#
# 1.  **Parallel Agent**: Simultaneously runs three specialist agents:
#     - `MuseumFinderAgent`: Finds a museum.
#     - `ConcertFinderAgent`: Finds a concert.
#     - `FoodieAgent`: Finds a restaurant.
# 2.  **Synthesis Agent**: Once all three parallel searches are complete, this final agent gathers the results (which were saved to the shared `state`) and formats them into a single, neat summary for the user.
#
# This pattern lets us get a lot of work done, fast! 🚀

# %% [markdown]
# ```
# +-------------------------------+
# |  parallel_planner_agent ⚡     |
# | SequentialAgent:              |
# | 1. Run parallel research      |
# | 2. Synthesize results         |
# +---------------+---------------+
#                 |
#      +----------+----------------------+
#      |                                 |
#      v                                 v
# +-------------------------+       +-----------------------------+
# | parallel_research_agent ⚡   |   | synthesis_agent 📋          |
# | ParallelAgent:              |   | Combine results            |
# | - museum_finder_agent 🖼️     |   | Output: Bulleted summary   |
# | - concert_finder_agent 🎵    |   +-----------------------------+
# | - restaurant_finder_agent 🍽️ |
# +-------------------------+
#
# Final Output:
# • Museum: XYZ
# • Concert: Artist at Venue
# • Restaurant: ABC
# ```

# %%
# --- Agent Definitions for a Parallel Workflow ---

# Specialist Agent 1
museum_finder_agent = Agent(
    name="museum_finder_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are a museum expert. Find the best museum based on the user's query. Output only the museum's name.",
    output_key="museum_result"
)

# Specialist Agent 2
concert_finder_agent = Agent(
    name="concert_finder_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are an events guide. Find a concert based on the user's query. Output only the concert name and artist.",
    output_key="concert_result"
)

# We can reuse our foodie_agent for the third parallel task!
# Just need to give it a new output_key for this workflow.
# restaurant_finder_agent = foodie_agent.copy(update={"output_key": "restaurant_result"})
restaurant_finder_agent = Agent(
    name="restaurant_finder_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are an expert food critic. Your goal is to find the best restaurant based on a user's request.

    When you recommend a place, you must output *only* the name of the establishment.
    For example, if the best sushi is at 'Jin Sho', you should output only: Jin Sho
    """,
    output_key="restaurant_result" # Set the correct output key for this workflow
)


# ✨ The ParallelAgent runs all three specialists at once ✨
parallel_research_agent = ParallelAgent(
    name="parallel_research_agent",
    sub_agents=[museum_finder_agent, concert_finder_agent, restaurant_finder_agent]
)

# Agent to synthesize the parallel results
synthesis_agent = Agent(
    name="synthesis_agent", model="gemini-2.5-flash",
    instruction="""You are a helpful assistant. Combine the following research results into a clear, bulleted list for the user.
    - Museum: {museum_result}
    - Concert: {concert_result}
    - Restaurant: {restaurant_result}
    """
)

# ✨ The SequentialAgent runs the parallel search, then the synthesis ✨
parallel_planner_agent = SequentialAgent(
    name="parallel_planner_agent",
    sub_agents=[parallel_research_agent, synthesis_agent],
    description="A workflow that finds multiple things in parallel and then summarizes the results."
)

print("🤖 Agent team supercharged with a ParallelAgent workflow!")
# Out:
# 🤖 Agent team supercharged with a ParallelAgent workflow!

# %%
# --- Let's Test the Parallel Workflow! ---

async def run_parallel_workflow():
    """
    A test function that invokes the ParallelAgent within a SequentialAgent.
    It demonstrates how to gather different pieces of information at the same time
    and then synthesize them into a single response.
    """

    # 1. Define a query that requires multiple, independent pieces of information.
    # This is a perfect use case for parallel execution!
    query = "I'm planning a trip to San Francisco. Find me the best art museum, a cool rock concert, and the best Italian restaurant."

    print(f"\n{'='*60}\n🗣️  Processing Query: '{query}'\n{'='*60}")
    print(f"🚀 Handing off the entire task to the '{parallel_planner_agent.name}'...")

    # 2. Create a session for the full workflow.
    session = await session_service.create_session(app_name=parallel_planner_agent.name, user_id=my_user_id)

    # 3. Run the query.
    # The ParallelPlannerAgent will automatically:
    #  - Kick off the three finder agents (museum, concert, restaurant) simultaneously. 🚀🚀🚀
    #  - Wait for all of them to complete.
    #  - Store their results in the session state ('museum_result', 'concert_result', 'restaurant_result').
    #  - Pass control to the synthesis_agent, which will have its prompt placeholders filled from the state.
    #  - Stream the final, synthesized response.
    await run_agent_query(parallel_planner_agent, query, session, my_user_id)

    print(f"\n--- ✅ '{parallel_planner_agent.name}' Workflow Complete ---")


# Execute the parallel test
await run_parallel_workflow()
# Out:
# ============================================================
# 🗣️  Processing Query: 'I'm planning a trip to San Francisco. Find me the best art museum, a cool rock concert, and the best Italian restaurant.'
# ============================================================
# 🚀 Handing off the entire task to the 'parallel_planner_agent'...
#
# 🚀 Running query for agent: 'parallel_planner_agent' in session: 'e49b976a-8700-41d7-b66b-626c81b9a39a'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""For art museums in San Francisco, the **San Francisco Museum of Modern Art (SFMOMA)** is a strong contender for the "best" and is highly recommended by experts. It's one of the largest museums of modern and contemporary art in the United States, featuring a vast collection and regularly hosting new exhibitions. SFMOMA has expanded its gallery space, making it the largest museum of its kind in North America. It's praised for its world-renowned collection of modern masterpieces, diverse exhibitions, and a new rooftop garden. The museum is also conveniently located near Yerba Buena Gardens, hotels, and restaurants.
#
# Other notable art museums in San Francisco include:
# *   **de Young Museum**: Located in Golden Gate Park, it specializes in American art, international textile arts and costumes, African art, Oceanic art, and arts of the Americas. It's one of the most visited museums in the U.S. and San Francisco.
# *   **Legion of Honor**: Tucked away in the Sea Cliff neighborhood, it houses European painting, sculpture, and decorative arts, ancient art, and graphic arts, and features famous pieces like Rodin's "The Thinker".
# *   **Asian Art Museum**: This museum boasts one of the most comprehensive collections of Asian art and culture globally."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='timeout.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG2RjRBErtvwtdUMOjQ93yY77uNzYN9ncBZbglCkg6yJ_0JWkq8-mZdT1jbSWUNQoBA3s_k3svu81hk-sQLxvwAO_g41KBIJEap1bjaHQbhvgenXO0h5TKAfX3JdCev6pX5h29qvtLV08DbgatrU--QXVuFcY9d4CJmfJBWGtLW1mZAH2mZ__un'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='tripexpert.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGWCgxizB0DelbukAL6IJOiKMalHl7Uv8lzHblo26zZKQbZuE8CWyC-DmssjXZEY5GIqEkFlwEv-seS6LlRyx1JqN65hxBfLEikWmJX00Xl3fGKUBBIhrbONpVXWL4tmSpXQiQloBB2UClX4qggKndiUBPY3bOt3zvEJDvXHf6mR6OhMnc4Lz3CtlYGxSE06dn0gBT7jJc6C0k='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='tripexpert.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGskgDPmrYAoHscMM4oCC8g_aRyEMn3w7cqUqSBPU42HhhYAPVF3VP3mwryT36VtDXMFrjWCR4JqzOcqFTkxBHU5tqVQMmVrBKozxwiHL1KtX28AI3m4qT_YKQ6NVzEWcIpKfQLGUE2PLsO6oTjzPBGpqBpLjxM4Gr_PtVR7NRHmI4g5n3oyEXHj7rV44LM3RuxuvBWObrmh8RiGh4QzQh9Mw4NIvPbWF2tgCu0'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sfmoma.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGzWPB8G0TXYO57GTDPWYaiFudBNNVW8L6FOmk3ksxwHQyq-kRSD92Mh_Ll3Ejm7rQ1W21ehs__UTBiB7hVSKYjueQZ0uOcYaZJ1pHjNDhA98Jb'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='modernluxury.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHOrfH61Cl8aVWyyC10UGuyX9_9zvxmCyTUo1r069-KOzWjk3LiLpIzGfHLpSzpSW4e6762fayYhKyk59EN6W_CbasG2OYxFwVzqjW0ypV7iArc9r2uLDsMTTe_cCoZ0XlPO9h3cWC1CicdJB9g8wNmi04='
#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=159,
#         text='For art museums in San Francisco, the **San Francisco Museum of Modern Art (SFMOMA)** is a strong contender for the "best" and is highly recommended by experts'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         4,
#       ],
#       segment=Segment(
#         end_index=311,
#         start_index=161,
#         text="It's one of the largest museums of modern and contemporary art in the United States, featuring a vast collection and regularly hosting new exhibitions"
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#       ],
#       segment=Segment(
#         end_index=409,
#         start_index=313,
#         text='SFMOMA has expanded its gallery space, making it the largest museum of its kind in North America'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         5,
#         1,
#       ],
#       segment=Segment(
#         end_index=527,
#         start_index=411,
#         text="It's praised for its world-renowned collection of modern masterpieces, diverse exhibitions, and a new rooftop garden"
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         6,
#       ],
#       segment=Segment(
#         end_index=618,
#         start_index=529,
#         text='The museum is also conveniently located near Yerba Buena Gardens, hotels, and restaurants'
#       )
#     ),
#     <... 4 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH47h-9k79sJBukLz7MZCn2xu41WcqvH5ajgRW3gr-RikFl-U75X8NY7zjkmxx8VL_oN84qK5W96KBIAlygdm8iDCyKqLtQmX_2jGUQ4P8s4F1SMU1ksqwrBwhdZKhsXylCb_WmCW0hAwwAFj9H3t_Q6ZCGXrTiTd2nJe0GwYjxP4CzEOi65MdhP3PHhRsV21JBHMsX-4ta6suMjSuqnjd9qnfLgbAB">top rated art museums San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFG9uFujOjObXVsURKx0dLWKkCWjx7Fc1u0jZR42ud41bN8WpVG1oXNpssn2LbQXqYm6JcZn-M7P-MhDPf_x4ADzMaanepUR9lul3xawSne06duuHIX39WVz4iVUEidDI1IRdimvkyLOE6hNdRGhU8XClRwJmNEALJOmJPk_j6X0DiMhYde6T01xziqm90Pl_mT_egA5Cn2Y5KJhEa9gNbt3UI4">best art museum in San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGTxnbyMXrJvKJ62ScgQcSmDtM2i5MIw0cF7FDYXvGvi2O2ax-uiz4B3Kq1BgeuqpOaxVqp1bUXpiCTVI2s_6KVQ0oRU-ogSoevZA-NLEeg2LiWOxPUbLPOdnXsV_EL0MWn5s58fVEt_JFO1UAQtwlvhefTd8gLT8LNAAw--gEB9-QpCcEPcOfZm83DeEQK0d3-hxbkit6tZtuFZaijjhlnzPnX">San Francisco art museum reviews</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best art museum in San Francisco',
#     'top rated art museums San Francisco',
#     'San Francisco art museum reviews',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=298,
#   prompt_token_count=73,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=73
#     ),
#   ],
#   thoughts_token_count=116,
#   total_token_count=487
# ) invocation_id='e-7e965d58-c168-4414-be12-45a37cbdbd69' author='museum_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'museum_result': 'For art museums in San Francisco, the **San Francisco Museum of Modern Art (SFMOMA)** is a strong contender for the "best" and is highly recommended by experts. It\'s one of the largest museums of modern and contemporary art in the United States, featuring a vast collection and regularly hosting new exhibitions. SFMOMA has expanded its gallery space, making it the largest museum of its kind in North America. It\'s praised for its world-renowned collection of modern masterpieces, diverse exhibitions, and a new rooftop garden. The museum is also conveniently located near Yerba Buena Gardens, hotels, and restaurants.\n\nOther notable art museums in San Francisco include:\n*   **de Young Museum**: Located in Golden Gate Park, it specializes in American art, international textile arts and costumes, African art, Oceanic art, and arts of the Americas. It\'s one of the most visited museums in the U.S. and San Francisco.\n*   **Legion of Honor**: Tucked away in the Sea Cliff neighborhood, it houses European painting, sculpture, and decorative arts, ancient art, and graphic arts, and features famous pieces like Rodin\'s "The Thinker".\n*   **Asian Art Museum**: This museum boasts one of the most comprehensive collections of Asian art and culture globally.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch='parallel_research_agent.museum_finder_agent' id='9a65b022-1f80-499b-8761-68a8732bba95' timestamp=1753979520.230094
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Dead & Company'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='jambase.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFPmk5Xtjrejo3syGAtaQETYik1eqi70APRuEdiqRoePuBkk4L2DJRgZFcx3MsANJhFZhzJJlWspHyLke_9CpW_MgpZUo6d67Szqbjk-T9dHLIOEiWtOcbtJsjJzunwYf-BRGdRLCCyZsh2OJfWrG_CRYWbZIdpVsM-gIsRfnm3lY1-UPuHSza-nLCwoRWeufHU'
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=14,
#         text='Dead & Company'
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFejNf9b2CG6yWD8JNUb-0kc5jfpXDdkQMYareKD5CePqNoO4TH08vI5j12y2aZ6RhmLzuXtmksQBoAmLLVC5l6bEMFfetYqPtaJTXaFfjPeSgEZDpuTq6snqMvKcIB0ppz4aBvxloLbPzLvEbYift23T0wN91k8cL1EUS96ie5pGjeyf7huotL5NlAYCh5mLsew2OoILkisIuEw99OfA==">rock concerts San Francisco</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'rock concerts San Francisco',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=18,
#   prompt_token_count=72,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=72
#     ),
#   ],
#   thoughts_token_count=541,
#   total_token_count=631
# ) invocation_id='e-7e965d58-c168-4414-be12-45a37cbdbd69' author='concert_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'concert_result': 'Dead & Company'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch='parallel_research_agent.concert_finder_agent' id='0187ce37-172b-42f7-a53e-c07c114fd20b' timestamp=1753979520.415064
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""For art museums, the San Francisco Museum of Modern Art (SFMOMA) is highly recommended. It is one of the largest modern and contemporary art museums in the United States and offers free admission for guests 18 and younger. Other notable art museums include the Asian Art Museum, Legion of Honor, and the de Young Museum.
#
# Regarding rock concerts in August 2025, Dead & Company will be playing three 60th anniversary shows at Golden Gate Park. The Warfield is also known as a top venue for rock shows in the Bay Area. Additionally, the Great American Music Hall has several rock-related concerts in early August, including "Axial Tilt: A Grateful Dead 60th Anniversary Celebration" and "SadGirl" (surfer rock).
#
# For the best Italian restaurant, Cotogna is a popular choice known for its housemade pastas, spit-roasted and grilled meats, and seafood roasted in a wood-burning oven. Serafina is another highly-rated option, described as a cozy, upscale, and authentic Italian restaurant specializing in Roman cuisine and innovative fish dishes. Trattoria Contadina is a traditional, family-run Italian restaurant in the North Beach neighborhood. Fior d'Italia, established in 1886, is America's oldest Italian restaurant and is known for its traditional Italian food and elegant atmosphere."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sfmoma.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQE5c2WHcFa-qwZLDjgHvWa1-Jxwh3zRp1EpYmMfLPuqkAebd74-wj3loZRNJOec6fOOcPMKIToIyFJggMfz-DuJV3YIeJK-bEiX9jz9pHtrAG4='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='modernluxury.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGekekMDDnAUG4eLjmihOalPDLFKwTBxTecntTOyxwgpt6_29Xa-uRki0dQR465BfgU2HUt41jYUyUgmUpuLPSHEpZfB3vlMieT0sho_2uOWV07l3MS17kc0p6dYTD-f3_mnBZ83Jn31Ta-CIfHpN7Slw=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='wikipedia.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFiyHzN1yU66jYhVGJU-04oHwlJ-HBmYaJ3tF_7sqlfmgA2Q5O4vLDbd0F_wrAkAAooy-Hf11cmNj1Fku_jnMAz9k48bJbJFoqCewMzjXu0V5Ufs7CIe-bxGtHvcDehPJLp6FxeZgaDQ4luTJ_iR5kgb5yafMp-y3Rr_g=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='san-francisco-theater.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHEB25lAdiWxgG_V-off_R8WdKWjpEd-MpERNFrQK8Cowh5gFjD-1l0OjCJkT_JTwYxeiKDUdFq3Kn5KtBfLaXPGAsM_aESnd9t-mzXUiQByvvOJ3wIWD7-BjHG46TXpf82LE0vaTz0qdNFv8d8CyKKPR0v8pRGYDlypxtSWgA='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='thewarfieldtheatre.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGTeVlm9wYl5z4Cznf3ovE88g0T8Uz9fGfBCiJgP1nRz0cjmW9TTwadK1NVOrWATKA8ZgnQOAKAOhTTDqAlal0vmMJU5rDILSOV40pVIyIDL6oehh-TZ6wySqneVmY='
#       )
#     ),
#     <... 5 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=222,
#         start_index=88,
#         text='It is one of the largest modern and contemporary art museums in the United States and offers free admission for guests 18 and younger.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=320,
#         start_index=223,
#         text='Other notable art museums include the Asian Art Museum, Legion of Honor, and the de Young Museum.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=442,
#         start_index=322,
#         text='Regarding rock concerts in August 2025, Dead & Company will be playing three 60th anniversary shows at Golden Gate Park.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#       ],
#       segment=Segment(
#         end_index=516,
#         start_index=443,
#         text='The Warfield is also known as a top venue for rock shows in the Bay Area.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         5,
#       ],
#       segment=Segment(
#         end_index=709,
#         start_index=517,
#         text='Additionally, the Great American Music Hall has several rock-related concerts in early August, including "Axial Tilt: A Grateful Dead 60th Anniversary Celebration" and "SadGirl" (surfer rock).'
#       )
#     ),
#     <... 4 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFmuTqGPHeWA12R2WVTX5h0jDeFi1LeIbklMUSMzoBEOM9ksE9i_RJCvmPeNMuEEvsTKMErk63wPkU1cYbXFDoWZMQNZ087I6f2gnL1xbU1OfEzqzoOTZzIe5fbc7AgnFKDMgmAdEq9zmK-bSbpclMYgaATYglkKZ756NOMUJ6VJlWPeKukaFfV5H_lj9Uv8lbm3tzT2gGLzmTALCpoM2h2MgBTkItm4Q==">best Italian restaurant San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFm2WlmiUTYh5zfJZWvv0B_tIzjniFfKQwtHM76HClQ5remF6AfY7ymQVSs_JQ1AaRiblbMgSVbdQU-EIOA-W_18TWAnrgqdbjYorZLm_NPq57JZJRwpkBC5JPiixdk0cT8AAgYdE5B-Q3rIzcHWOcUFfKUyUd5XynwGms3Es550s9wo7CPIoOTDfhM4F7um_ItwCrpzzmpaOwV5n82Q2A=">best art museum San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF68WER2cp4GZHWU3qf5MjJ3EBZkZb6NKieTsy5SCHUkWMDcJrdE1DeZcDRAMaW6pf93uLEbshBCpfGmUCFatLT8FNilw7qXdrlKwsyXicds_58A9FYWvVG47KIK1mWX5GAEbpKlhk40SpzXl4AAP2JXmbYuQq0sHjADao7_Dc73RfZzrxfeOJh3YmklBEp_6HOsRKFKpfB_y3GAcdKP0qLKpn5HiY0TN24cgaT1Sk=">cool rock concerts San Francisco August 2025</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best art museum San Francisco',
#     'cool rock concerts San Francisco August 2025',
#     'best Italian restaurant San Francisco',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=314,
#   prompt_token_count=114,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=114
#     ),
#   ],
#   thoughts_token_count=184,
#   total_token_count=612
# ) invocation_id='e-7e965d58-c168-4414-be12-45a37cbdbd69' author='restaurant_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'restaurant_result': 'For art museums, the San Francisco Museum of Modern Art (SFMOMA) is highly recommended. It is one of the largest modern and contemporary art museums in the United States and offers free admission for guests 18 and younger. Other notable art museums include the Asian Art Museum, Legion of Honor, and the de Young Museum.\n\nRegarding rock concerts in August 2025, Dead & Company will be playing three 60th anniversary shows at Golden Gate Park. The Warfield is also known as a top venue for rock shows in the Bay Area. Additionally, the Great American Music Hall has several rock-related concerts in early August, including "Axial Tilt: A Grateful Dead 60th Anniversary Celebration" and "SadGirl" (surfer rock).\n\nFor the best Italian restaurant, Cotogna is a popular choice known for its housemade pastas, spit-roasted and grilled meats, and seafood roasted in a wood-burning oven. Serafina is another highly-rated option, described as a cozy, upscale, and authentic Italian restaurant specializing in Roman cuisine and innovative fish dishes. Trattoria Contadina is a traditional, family-run Italian restaurant in the North Beach neighborhood. Fior d\'Italia, established in 1886, is America\'s oldest Italian restaurant and is known for its traditional Italian food and elegant atmosphere.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch='parallel_research_agent.restaurant_finder_agent' id='baeb11bc-08f4-4ed2-9fe7-3c6f4e7c1e22' timestamp=1753979520.608412
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Here are some recommendations for your trip to San Francisco:
#
# *   **Best Art Museum:** The **San Francisco Museum of Modern Art (SFMOMA)** is highly recommended by experts and considered a strong contender for the "best." It's one of the largest modern and contemporary art museums in North America, featuring a vast, world-renowned collection, diverse exhibitions, and a new rooftop garden. It's also conveniently located. Other notable art museums include the de Young Museum, Legion of Honor, and the Asian Art Museum.
# *   **Cool Rock Concert:** **Dead & Company** will be playing three 60th-anniversary shows at Golden Gate Park in August 2025.
# *   **Best Italian Restaurant:** You have several excellent options:
#     *   **Cotogna:** A popular choice known for its housemade pastas, spit-roasted and grilled meats, and seafood roasted in a wood-burning oven.
#     *   **Serafina:** A highly-rated, cozy, and upscale restaurant specializing in authentic Roman cuisine and innovative fish dishes.
#     *   **Trattoria Contadina:** A traditional, family-run Italian restaurant located in the North Beach neighborhood.
#     *   **Fior d'Italia:** Established in 1886, it's America's oldest Italian restaurant, known for its traditional Italian food and elegant atmosphere."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=289,
#   prompt_token_count=1218,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=1218
#     ),
#   ],
#   thoughts_token_count=527,
#   total_token_count=2034
# ) invocation_id='e-7e965d58-c168-4414-be12-45a37cbdbd69' author='synthesis_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='8887bb7d-3f94-4aad-8a33-d4fefa65fc00' timestamp=1753979532.226484
#
# --------------------------------------------------
# ✅ Final Response:
# Here are some recommendations for your trip to San Francisco:
#
# *   **Best Art Museum:** The **San Francisco Museum of Modern Art (SFMOMA)** is highly recommended by experts and considered a strong contender for the "best." It's one of the largest modern and contemporary art museums in North America, featuring a vast, world-renowned collection, diverse exhibitions, and a new rooftop garden. It's also conveniently located. Other notable art museums include the de Young Museum, Legion of Honor, and the Asian Art Museum.
# *   **Cool Rock Concert:** **Dead & Company** will be playing three 60th-anniversary shows at Golden Gate Park in August 2025.
# *   **Best Italian Restaurant:** You have several excellent options:
#     *   **Cotogna:** A popular choice known for its housemade pastas, spit-roasted and grilled meats, and seafood roasted in a wood-burning oven.
#     *   **Serafina:** A highly-rated, cozy, and upscale restaurant specializing in authentic Roman cuisine and innovative fish dishes.
#     *   **Trattoria Contadina:** A traditional, family-run Italian restaurant located in the North Beach neighborhood.
#     *   **Fior d'Italia:** Established in 1886, it's America's oldest Italian restaurant, known for its traditional Italian food and elegant atmosphere.
# --------------------------------------------------
#
#
# --- ✅ 'parallel_planner_agent' Workflow Complete ---

# %% [markdown]
# ---
# ## Iterative Ideas with `LoopAgent` 🧠→🔁→🤖
#
# Sometimes a task isn't a straight line; it's a loop of refinement. A user might ask for a plan, but have constraints that require checking and re-planning. For this, the ADK provides the **`LoopAgent`**.
#
# The `LoopAgent` executes a sequence of sub-agents repeatedly until a condition is met. This is perfect for workflows involving trial and error, like planning a trip with a tight schedule.
#
# **Our New Workflow: The Perfectionist Planner**
#
# 1. **Planner Agent**: Proposes an itinerary (e.g., a museum and a restaurant).
# 2. **Critic Agent**: Checks the plan against a constraint (e.g., "Is the travel time between these two places less than 30 minutes?").
# 3. **Refiner Agent**: If the critic finds a problem, this agent takes the feedback and creates a new, improved plan. If the critic is happy, it calls a special `exit_loop` tool to stop the process.
#
# The `LoopAgent` manages this cycle, ensuring we don't get stuck in an infinite loop by setting a `max_iterations` limit.

# %% [markdown]
# ```
# +-------------------------------+
# |  iterative_planner_agent 🔁   |
# | SequentialAgent:              |
# | 1. Propose Plan               |
# | 2. Refine in loop (≤ 3 times) |
# +---------------+---------------+
#                 |
#      +----------+----------+
#      |                     |
#      v                     v
# +----------------+   +-----------------------+
# | planner_agent  |   | refinement_loop 🔁     |
# | Propose plan   |   | LoopAgent             |
# | e.g., Activity +  | 1. Critic (time check) |
# | Restaurant       | 2. Refiner (fix/exit)   |
# +----------------+   +-----------------------+
#
# Uses shared state: {current_plan}, {criticism}
# Exits when: "Plan is feasible..."
#
# ```

# %%
# --- Agent Definitions for an Iterative Workflow ---

# A tool to signal that the loop should terminate
COMPLETION_PHRASE = "The plan is feasible and meets all constraints."
def exit_loop(tool_context: ToolContext):
  """Call this function ONLY when the plan is approved, signaling the loop should end."""
  print(f"  [Tool Call] exit_loop triggered by {tool_context.agent_name}")
  tool_context.actions.escalate = True
  return {}

# Agent 1: Proposes an initial plan
planner_agent = Agent(
    name="planner_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are a trip planner. Based on the user's request, propose a single activity and a single restaurant. Output only the names, like: 'Activity: Exploratorium, Restaurant: La Mar'.",
    output_key="current_plan"
)

# Agent 2 (in loop): Critiques the plan
critic_agent = Agent(
    name="critic_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction=f"""You are a logistics expert. Your job is to critique a travel plan. The user has a strict constraint: total travel time must be short.
    Current Plan: {{current_plan}}
    Use your tools to check the travel time between the two locations.
    IF the travel time is over 45 minutes, provide a critique, like: 'This plan is inefficient. Find a restaurant closer to the activity.'
    ELSE, respond with the exact phrase: '{COMPLETION_PHRASE}'""",
    output_key="criticism"
)

# Agent 3 (in loop): Refines the plan or exits
refiner_agent = Agent(
    name="refiner_agent", model="gemini-2.5-flash", tools=[exit_loop],
    instruction=f"""You are a trip planner, refining a plan based on criticism.
    Original Request: {{session.query}}
    Critique: {{criticism}}
    IF the critique is '{COMPLETION_PHRASE}', you MUST call the 'exit_loop' tool.
    ELSE, generate a NEW plan that addresses the critique. Output only the new plan names, like: 'Activity: de Young Museum, Restaurant: Nopa'.""",
    output_key="current_plan"
)

# ✨ The LoopAgent orchestrates the critique-refine cycle ✨
refinement_loop = LoopAgent(
    name="refinement_loop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=3
)

# ✨ The SequentialAgent puts it all together ✨
iterative_planner_agent = SequentialAgent(
    name="iterative_planner_agent",
    sub_agents=[planner_agent, refinement_loop],
    description="A workflow that iteratively plans and refines a trip to meet constraints."
)

print("🤖 Agent team updated with an iterative LoopAgent workflow!")
# Out:
# 🤖 Agent team updated with an iterative LoopAgent workflow!

# %%
# --- Let's Test the Iterative Workflow! ---

async def run_iterative_workflow():
    """
    A test function that invokes the LoopAgent to iteratively refine a plan
    until it meets a specific constraint.
    """

    # 1. Define a query where the initial, naive plan is likely to fail the constraint.
    # Here, Muir Woods (in Marin County) and San Jose are very far apart,
    # guaranteeing the critic_agent will find the travel time too long.
    query = "Plan a day for me. I want to see the redwoods at Muir Woods and eat at a top-rated Vietnamese restaurant in San Jose."

    print(f"\n{'='*60}\n🗣️  Processing Query: '{query}'\n{'='*60}")
    print(f"🚀 Handing off the task to the '{iterative_planner_agent.name}'...")

    # 2. Create a session.
    session = await session_service.create_session(app_name=iterative_planner_agent.name, user_id=my_user_id)


    # 3. Run the query.
    # The iterative_planner_agent will:
    #  - Call `planner_agent` to create an initial plan (Muir Woods & a San Jose restaurant).
    #  - Start the `refinement_loop`.
    #  - LOOP 1: 🔄
    #    - `critic_agent` checks the long travel time and outputs a critique.
    #    - `refiner_agent` receives the critique and proposes a *new* plan (e.g., Muir Woods & a closer restaurant in Marin).
    #  - LOOP 2: 🔄
    #    - `critic_agent` checks the new, shorter travel time and finds it acceptable. It outputs the completion phrase.
    #    - `refiner_agent` sees the completion phrase and calls the `exit_loop` tool, which escalates and terminates the loop.
    #  - The final, approved plan from the previous step is returned as the result.
    await run_agent_query(iterative_planner_agent, query, session, my_user_id)

    print(f"\n--- ✅ '{iterative_planner_agent.name}' Workflow Complete ---")


# Execute the iterative test
await run_iterative_workflow()
# Out:
# ============================================================
# 🗣️  Processing Query: 'Plan a day for me. I want to see the redwoods at Muir Woods and eat at a top-rated Vietnamese restaurant in San Jose.'
# ============================================================
# 🚀 Handing off the task to the 'iterative_planner_agent'...
#
# 🚀 Running query for agent: 'iterative_planner_agent' in session: '6c2ffb25-3a69-4dab-b9af-5b926821923a'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Activity: Muir Woods National Monument
# Restaurant: Thien Long"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG-jRnAi8su-buoq5eBcVk7Kr5msP1Zga0sLrwoZTjLVEE2SDAKdmzXsfj62hlohoUkk09f84VXTq7nF77GYLMZ8ZfgqDx_Sb9K6iDGH0nD3EYq7lY7COgbtrfmH11mXRtwSQM1_muC5sn9VH1kp1RfPuzYGQwBR9oLo7zDBwz6mUxol7nspEIHFYJ2UKfQetxx_2xe7VBCXPEPVnBiulde7d2AW_llIYEMTEU=">top-rated Vietnamese restaurant San Jose</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'top-rated Vietnamese restaurant San Jose',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=30,
#   prompt_token_count=87,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=87
#     ),
#   ],
#   thoughts_token_count=61,
#   total_token_count=178
# ) invocation_id='e-5011f31e-9613-4a28-b385-bd0236657d86' author='planner_agent' actions=EventActions(skip_summarization=None, state_delta={'current_plan': 'Activity: Muir Woods National Monument\nRestaurant: Thien Long'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='4e84438f-3022-422f-abdc-081dbdb549ad' timestamp=1753979567.265617
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='This plan is inefficient. Find a restaurant closer to the activity.'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHkO34xEiD20TI8tFmdZM9bL5trD2GeZ3WK4qFXejL3i26suqWDTQPkEAuPkM660cOKb_1gPX996q80t6OfCb45ay4WFck6rk4_9cpLTj8eZWxRAweZM60kt_W9oncXDlU98kvIGXhAnPyIXWj34rHITq0JdLmJYf5iD05K3WmtCoRpqjjf0XDqOfaM_iI0xoIOEi1-dlsjLKyklyDDUWfm_fLDr-oFxDsvNYum44GaA_0ObQOeXx6Hx8-M2m4fVRZLmsNO">Muir Woods National Monument to Thien Long San Jose driving time</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Muir Woods National Monument to Thien Long travel time',
#     'Muir Woods National Monument',
#     'Thien Long restaurant San Jose',
#     'Muir Woods National Monument to Thien Long San Jose driving time',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=74,
#   prompt_token_count=183,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=183
#     ),
#   ],
#   thoughts_token_count=419,
#   total_token_count=676
# ) invocation_id='e-5011f31e-9613-4a28-b385-bd0236657d86' author='critic_agent' actions=EventActions(skip_summarization=None, state_delta={'criticism': 'This plan is inefficient. Find a restaurant closer to the activity.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='7baa7152-22ec-43b9-8621-3ab9994bc1c7' timestamp=1753979576.175617
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Activity: Muir Woods National Monument, Restaurant: Slanted Door'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=12,
#   prompt_token_count=233,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=233
#     ),
#   ],
#   thoughts_token_count=263,
#   total_token_count=508
# ) invocation_id='e-5011f31e-9613-4a28-b385-bd0236657d86' author='refiner_agent' actions=EventActions(skip_summarization=None, state_delta={'current_plan': 'Activity: Muir Woods National Monument, Restaurant: Slanted Door'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='71b09a6a-ee29-418c-b8b0-2c8f29c05857' timestamp=1753979588.921945
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Muir Woods National Monument is located 12 to 16 miles north of San Francisco. Driving from San Francisco to Muir Woods takes approximately 28 to 45 minutes without traffic. However, it's important to note that Muir Woods is a popular tourist destination with limited parking, and visitors are required to make a parking reservation in advance.
#
# The Slanted Door restaurant is located in San Francisco. Given the travel time and potential for traffic, especially considering the need for parking reservations at Muir Woods, the travel time between the two locations would likely exceed 45 minutes.
#
# This plan is inefficient. Find a restaurant closer to the activity."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='wikipedia.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEIEluwub5XG12yl8LgIjSeVCIm3DDfI6G3Mv-0eacQh4uksDiMXejbpqE9FKfIE6KZWUTf1CwT4tmmsWV6Z_FRb6wPU5pOrqg7MLW7ekyU1Jeabgg4ygkDCNLq8cmNOGSRbETWlBGtuEE4SjDIjIBFTRe8_w=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='extranomical.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFQSfHoGeqcSOW2WGJBxjCiP2PfZcrtyOmowuifqv0zWF8KFA60xWoi-9Mn2Z3MgFrsYiwJJmM-yqoCe6QyN_4DohOQJ9xe4d6BSUic1x_j1zLx_UM7qPaH8_U8Oq-Kkob1kHhjXa_1hnMIQOCcvirUAXmHyAQ8m7ZDhQA8HCP4V_R1CSHg9Knh'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='mycaliforniatravels.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEmYoltxCfAQiFeT9rsoEnqUNzAUCCkdbkMx_dldhwvszjSBYZ9zVufGOf-Ai6IseYoFUcNnYSycGcf8_5AkfIzZ3B69_dib0KJ79dK4diWKryRmORfNQbJuXWz1oHfus1S2dfsKFcQ-XZuVIjCDvi6RSvfhMPb5G1LF_PrZbQUEUo='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='rome2rio.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGBUkHoWSEwuSlV-eoS4yjsgrQRpSoYNtn5umZd4jYqeJoS5ho7sV7G3vJNvxFg9yozMKOVq6FlpdheCvk1G0B3RTIMUNhyVeNxOKrpnuTmJHyTOMoziZTwpsdu5Te8eJ_IISfVRDpZ70BYOJ1cIDT9DUcT4WtcdudeuePOc7E0'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='nps.gov',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFPlP_MmWSVgbzV-b0yhcFOHNuOeZLOWwcL-Jzr83MezzFoQGsgW_kZeerceUOmQmQp-Hb2w6sCnerUnBRebMZSvN2zZd6y-rJomFmaNJbORga8Wy47zvwdznQpFfHnLQveKwk_uFBn-Na1oLhFN6I='
#       )
#     ),
#     <... 1 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=78,
#         text='Muir Woods National Monument is located 12 to 16 miles north of San Francisco.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=173,
#         start_index=79,
#         text='Driving from San Francisco to Muir Woods takes approximately 28 to 45 minutes without traffic.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#         5,
#         2,
#       ],
#       segment=Segment(
#         end_index=344,
#         start_index=174,
#         text="However, it's important to note that Muir Woods is a popular tourist destination with limited parking, and visitors are required to make a parking reservation in advance."
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFN2vJ77lGIi-KcxV0PP3NfLA8ZVZoOcwvTV2wG8PAnRvNMva1O9mC5UiPtEel0x54PZWaADcZGDQL3mXN3cciJCimIgxBx_1nZUbo8CE3q4kEEXA-ekG7K_q3-Xoip3XNVcYHZommQyxmaai4T-hYgksuTgW5_l-EPL2HXn0MsqnXm5hfipxeWbs6TEWJAFlBypxZnE7Zg-nqMcpu7rvWy-1E6sTfnolh35JKgYX2LopAsA70lV8nL_mfg">travel time Muir Woods National Monument to Slanted Door</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFQhHfddOolRh_qWwXpCOboO2vv_8HeZf2ZRQj8TgoFdSrbk67MVqG-HsFXOPoQjdPPpxgJ_F_3sCIwbIbSDiVjwdx3n-AM-Z8-kJoi5jDLKDWXwM2y1qGQUx4mSvFCnsm5N3P3Ws_znaguvbSCu3ZUoJIVj9E-qhDdpp6sCXJbgRVSWGWwsusWju3qAECYseoM2b2UUDviGnfho4UJv0TN0p9TCD5tPl0fogJxeT_Ysz3XmIlYItfh">distance Muir Woods National Monument to Slanted Door</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'travel time Muir Woods National Monument to Slanted Door',
#     'distance Muir Woods National Monument to Slanted Door',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=165,
#   prompt_token_count=221,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=221
#     ),
#   ],
#   thoughts_token_count=245,
#   total_token_count=631
# ) invocation_id='e-5011f31e-9613-4a28-b385-bd0236657d86' author='critic_agent' actions=EventActions(skip_summarization=None, state_delta={'criticism': "Muir Woods National Monument is located 12 to 16 miles north of San Francisco. Driving from San Francisco to Muir Woods takes approximately 28 to 45 minutes without traffic. However, it's important to note that Muir Woods is a popular tourist destination with limited parking, and visitors are required to make a parking reservation in advance.\n\nThe Slanted Door restaurant is located in San Francisco. Given the travel time and potential for traffic, especially considering the need for parking reservations at Muir Woods, the travel time between the two locations would likely exceed 45 minutes.\n\nThis plan is inefficient. Find a restaurant closer to the activity."}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='10498c72-5cc4-4a1d-9ee9-b4849eec35d4' timestamp=1753979591.140892
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Activity: Muir Woods National Monument, Restaurant: A restaurant closer to the activity'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=15,
#   prompt_token_count=508,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=508
#     ),
#   ],
#   thoughts_token_count=112,
#   total_token_count=635
# ) invocation_id='e-5011f31e-9613-4a28-b385-bd0236657d86' author='refiner_agent' actions=EventActions(skip_summarization=None, state_delta={'current_plan': 'Activity: Muir Woods National Monument, Restaurant: A restaurant closer to the activity'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='bd5d66e9-e5b7-4b45-bcde-b06e0dc563b0' timestamp=1753979601.530551
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""The Muir Woods National Monument is surrounded by several towns with dining options that are much closer than San Jose, such as Mill Valley and Sausalito.
#
# Driving from Muir Woods to Mill Valley takes approximately 10 minutes. Sausalito is about an 8-mile drive, taking around 15 minutes. Both towns offer a variety of restaurants.
#
# The plan is feasible and meets all constraints."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='rome2rio.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG1nKvWRLKTIemyoaXBEQNCmY1Dr8n0Yjb5WVP0e8hgSDPUf5lE0hqKuyr5xRW86QEf9y1xyGvab6Zdnt4FMvhLSZojG_EMUog1GOtLHt0GdSkdd3DHejyWrbaKcv3n8ukyLShhuP_vwuKLS1FF5zMZjkSIoLPiq31VGxxr'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='rome2rio.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHlMA-f63eMabkuM9SV0xvAwp7hKYwVGQTRBzPRIzrOIPdaCEWLPbhtbWiANmz7Oyhabs7z7AOA9vBpMSD1DZNIklF77jOHTyhzJ_zLPdtxn4JZYsppQEyf70kjWYlEvAGz-M_Pm--eyOrpdKL_N-CJGV7xxQea9HYgVbTDGrs='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='opentable.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEdJgtmof2Cnk62lhg4E8xZ7HPUVQmSFDHN-y9ulkt4tw4M6G9nntJLTIYBMlJnQ6LHITqfdpLTBy5-kVLoYz124Gozm9hpbegxSoYjgJK9C2LjLZAJrHGJIWbv_TUHJ0b-6R4pywIkb-o9Iw8iMTlJSmnHPe3utnBSD6P12mubE7dB-9SKBcHbH7SUoFmthH2YovsFYRoQ'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sightseeingworld.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEcjHNI65V5J4PPR-Kk-t17irVUuVlE9Dcgt6OLVKcxn1xS0TGatJ0HB8ufZH8I5FW6lMP3SVY6nxXq18B3zCSJBI5sdUdlmYF0oBx6WYOm2pmqfe26oInDttMpessfFoCRw9ExrVONk0TdYIes52rrx6Ct-5KnwZLvIBQeYoIu8NA='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='rome2rio.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGJsFY9O3QyQBhZUVVvOJ1ZbRzCPWg6olGMS1WdTULb7Vat5HP7-htXjOUssZjNOOHDou25I9wo-Ncv53fLh764dOa3s3kZzty-jiW87smwAe5ElnLkaEu5ECtDBanb4ONW0R2hLbe0lfkoknYukINCjxARGPHsB7dKXxY9YwQ='
#       )
#     ),
#     <... 1 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#         3,
#       ],
#       segment=Segment(
#         end_index=154,
#         text='The Muir Woods National Monument is surrounded by several towns with dining options that are much closer than San Jose, such as Mill Valley and Sausalito.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#         4,
#       ],
#       segment=Segment(
#         end_index=226,
#         start_index=156,
#         text='Driving from Muir Woods to Mill Valley takes approximately 10 minutes.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         5,
#       ],
#       segment=Segment(
#         end_index=288,
#         start_index=227,
#         text='Sausalito is about an 8-mile drive, taking around 15 minutes.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#         3,
#       ],
#       segment=Segment(
#         end_index=331,
#         start_index=289,
#         text='Both towns offer a variety of restaurants.'
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGPjAZ6GTL2CKLjc4wCfn-o2NwgGy5MBO1HoRtvltECbNw1LZW_-O5W2UQ0vArAMG8zu3CxmLslyb9X5ol10MVuMi0yIJBKikq7Fqov7Qd7tGR5o3h9HKaj9pOGXf4XCzEO5wghcSTCng1JogFW3K7WK7u9aiNf2GeSl-DjA-vSb1iRQ7FJCfJChQg_mJz89BKrwwBg2SstnnjpR_bPqe_bsjGrKjBP-tbj">driving time Muir Woods to Mill Valley</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHAsgbiFcdsGBdQ8G4Ynnmg8RnINAdgyRs07JhhcJPb1LJbgEIj2Qt5USs9VuMpRsoajFFtV9qU4pBFHwMz3UFu1K3Xcix9rmfPkE1Qjq5Pe9saIKFRf5-aOZALUQ5HpXeH7LRmFHsZg9hHeJt4bf9VH64DJPfdFU_KDsmxFidcVQgp1r4OYfvtKGEr2O69erpCxVvOwha3fta39tGSuTK2bkIqYiQUK88z5QDnSKFPBANMRmyIWuezEu4EPdk=">restaurants near Muir Woods National Monument travel time</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHwmS_mpdnRL2zq7iduy0PpACv6X5OBZ66xoCNpsIAHM6A0w5Ee0Aa3nG0kPkCnrqNeQ9FQth0a3XA4IZmPAz3Lr9FwvM25ut-YSlwTuJ9uRSDr8hp3NyfJ7UU6fO1LqP0AFiLO9ND-gifXeIWjOD5Pf8tsQ35iYQbm3Xjr5nMScqwybztlxY_G2jltzib_455SwBQotT18h5K9uTIk6fkFg6z2XrQmBA==">driving time Muir Woods to Sausalito</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'restaurants near Muir Woods National Monument travel time',
#     'driving time Muir Woods to Mill Valley',
#     'driving time Muir Woods to Sausalito',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=120,
#   prompt_token_count=385,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=385
#     ),
#   ],
#   thoughts_token_count=268,
#   total_token_count=773
# ) invocation_id='e-5011f31e-9613-4a28-b385-bd0236657d86' author='critic_agent' actions=EventActions(skip_summarization=None, state_delta={'criticism': 'The Muir Woods National Monument is surrounded by several towns with dining options that are much closer than San Jose, such as Mill Valley and Sausalito.\n\nDriving from Muir Woods to Mill Valley takes approximately 10 minutes. Sausalito is about an 8-mile drive, taking around 15 minutes. Both towns offer a variety of restaurants.\n\nThe plan is feasible and meets all constraints.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='ab838c5e-ed9d-49f0-a034-fb1895dedbf7' timestamp=1753979602.80929
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={},
#         id='adk-ff86593a-01a5-46a8-a44c-fd2326dbd0e0',
#         name='exit_loop'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=10,
#   prompt_token_count=567,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=567
#     ),
#   ],
#   thoughts_token_count=235,
#   total_token_count=812
# ) invocation_id='e-5011f31e-9613-4a28-b385-bd0236657d86' author='refiner_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=set() branch=None id='7dd2cccf-9561-4b32-8881-fb4d045eebd0' timestamp=1753979614.255
#   [Tool Call] exit_loop triggered by refiner_agent
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-ff86593a-01a5-46a8-a44c-fd2326dbd0e0',
#         name='exit_loop',
#         response={}
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None invocation_id='e-5011f31e-9613-4a28-b385-bd0236657d86' author='refiner_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=True, requested_auth_configs={}) long_running_tool_ids=None branch=None id='5753bd3d-5270-4343-a68f-272dd50d9855' timestamp=1753979615.891195
#
# --------------------------------------------------
# ✅ Final Response:
# An error occurred: 500 INTERNAL. {'error': {'code': 500, 'message': 'An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting', 'status': 'INTERNAL'}}
# --------------------------------------------------
#
#
# --- ✅ 'iterative_planner_agent' Workflow Complete ---

# %% [markdown]
# ## The Agent-as-a-Tool: Consulting a Specialist 🧑‍🍳
#
# Why build one agent that does everything when you can build a **team of specialist agents?** The **Agent-as-a-Tool** pattern allows one agent to delegate a task to another agent.
#
# **Key Concept:** This is different from a sub-agent. When Agent A calls Agent B as a tool, Agent B's response is passed **back to Agent A**. Agent A then uses that information to form its own final response to the user. It's a powerful way to compose complex behaviors from simpler, focused, and reusable agents.

# %% [markdown]
# ### How It Works
#
# Our top-level agent, the `trip_data_concierge_agent`, acts as the **Orchestrator**. It has two tools at its disposal:
#
# 1.  `call_db_agent`: A function that internally calls our `db_agent` to fetch raw data.
# 2.  `call_concierge_agent`: A function that calls the `concierge_agent`.
#
# The `concierge_agent` itself has a tool: the `food_critic_agent`.
#
# The flow for a complex query is:
#
# 1.  **User** asks the `trip_data_concierge_agent` for a hotel and a nearby restaurant.
# 2.  The **Orchestrator** first calls `call_db_agent` to get hotel data.
# 3.  The data is saved in `tool_context.state`.
# 4.  The **Orchestrator** then calls `call_concierge_agent`, which retrieves the hotel data from the context.
# 5.  The `concierge_agent` receives the request and decides it needs to use its own tool, the `food_critic_agent`.
# 6.  The `food_critic_agent` provides a witty recommendation.
# 7.  The `concierge_agent` gets the critic's response and politely formats it.
# 8.  This final, polished response is returned to the **Orchestrator**, which presents it to the user.

# %% [markdown]
#                          +-----------------------------------------------------------+
#                          |              🧭 Trip Data Concierge Agent                 |
#                          |-----------------------------------------------------------|
#                          |  Model: gemini-2.5-flash                                  |
#                          |  Description:                                             |
#                          |   Orchestrates database query and travel recommendation  |
#                          |-----------------------------------------------------------|
#                          |  🔧 Tools:                                                |
#                          |   1. call_db_agent                                        |
#                          |   2. call_concierge_agent                                 |
#                          +-----------------------------------------------------------+
#                                       /                                \
#                                      /                                  \
#                                     ▼                                    ▼
#         +-------------------------------------------+    +---------------------------------------------+
#         |            🔧 Tool: call_db_agent         |    |         🔧 Tool: call_concierge_agent        |
#         |-------------------------------------------|    |---------------------------------------------|
#         | Calls: db_agent                           |    | Calls: concierge_agent                       |
#         |                                           |    | Uses data from db_agent for recommendations |
#         +-------------------------------------------+    +---------------------------------------------+
#                                 |                                          |
#                                 ▼                                          ▼
#        +--------------------------------------------+   +------------------------------------------------+
#        |              📦 db_agent                   |   |             🤵 concierge_agent                  |
#        |--------------------------------------------|   |------------------------------------------------|
#        | Model: gemini-2.5-flash                    |   | Model: gemini-2.5-flash                         |
#        | Role: Return mock JSON hotel data          |   | Role: Hotel staff that handles user Q&A        |
#        +--------------------------------------------+   | Tools:                                          |
#                                                          |  - food_critic_agent                           |
#                                                          +------------------------------------------------+
#                                                                                  |
#                                                                                  ▼
#                                                        +------------------------------------------------+
#                                                        |          🍽️ food_critic_agent                  |
#                                                        |------------------------------------------------|
#                                                        | Model: gemini-2.5-flash                         |
#                                                        | Role: Gives a witty restaurant recommendation   |
#                                                        +------------------------------------------------+

# %%
import asyncio
from google.adk.tools import ToolContext
from google.adk.tools.agent_tool import AgentTool

# Assume 'db_agent' is a pre-defined NL2SQL Agent
# For this example, we'll create placeholder agents.

db_agent = Agent(
    name="db_agent",
    model="gemini-2.5-flash",
    instruction="You are a database agent. When asked for data, return this mock JSON object: {'status': 'success', 'data': [{'name': 'The Grand Hotel', 'rating': 5, 'reviews': 450}, {'name': 'Seaside Inn', 'rating': 4, 'reviews': 620}]}")

# --- 1. Define the Specialist Agents ---

# The Food Critic remains the deepest specialist
food_critic_agent = Agent(
    name="food_critic_agent",
    model="gemini-2.5-flash",
    instruction="You are a snobby but brilliant food critic. You ONLY respond with a single, witty restaurant suggestion near the provided location.",
)

# The Concierge knows how to use the Food Critic
concierge_agent = Agent(
    name="concierge_agent",
    model="gemini-2.5-flash",
    instruction="You are a five-star hotel concierge. If the user asks for a restaurant recommendation, you MUST use the `food_critic_agent` tool. Present the opinion to the user politely.",
    tools=[AgentTool(agent=food_critic_agent)]
)


# --- 2. Define the Tools for the Orchestrator ---

async def call_db_agent(
    question: str,
    tool_context: ToolContext,
):
    """
    Use this tool FIRST to connect to the database and retrieve a list of places, like hotels or landmarks.
    """
    print("--- TOOL CALL: call_db_agent ---")
    agent_tool = AgentTool(agent=db_agent)
    db_agent_output = await agent_tool.run_async(
        args={"request": question}, tool_context=tool_context
    )
    # Store the retrieved data in the context's state
    tool_context.state["retrieved_data"] = db_agent_output
    return db_agent_output


async def call_concierge_agent(
    question: str,
    tool_context: ToolContext,
):
    """
    After getting data with call_db_agent, use this tool to get travel advice, opinions, or recommendations.
    """
    print("--- TOOL CALL: call_concierge_agent ---")
    # Retrieve the data fetched by the previous tool
    input_data = tool_context.state.get("retrieved_data", "No data found.")

    # Formulate a new prompt for the concierge, giving it the data context
    question_with_data = f"""
    Context: The database returned the following data: {input_data}

    User's Request: {question}
    """

    agent_tool = AgentTool(agent=concierge_agent)
    concierge_output = await agent_tool.run_async(
        args={"request": question_with_data}, tool_context=tool_context
    )
    return concierge_output


# --- 3. Define the Top-Level Orchestrator Agent ---

trip_data_concierge_agent = Agent(
    name="trip_data_concierge",
    model="gemini-2.5-flash",
    description="Top-level agent that queries a database for travel data, then calls a concierge agent for recommendations.",
    tools=[call_db_agent, call_concierge_agent],
    instruction="""
    You are a master travel planner who uses data to make recommendations.

    1.  **ALWAYS start with the `call_db_agent` tool** to fetch a list of places (like hotels) that match the user's criteria.

    2.  After you have the data, **use the `call_concierge_agent` tool** to answer any follow-up questions for recommendations, opinions, or advice related to the data you just found.
    """,
)

print(f"✅ Orchestrator Agent '{trip_data_concierge_agent.name}' is defined and ready.")
# Out:
# ✅ Orchestrator Agent 'trip_data_concierge' is defined and ready.

# %%
# --- Let's test the Trip Data Concierge Agent ---

async def run_trip_data_concierge():
    """
    Sets up a session and runs a query against the top-level
    trip_data_concierge_agent.
    """
    # Create a new, single-use session for this query
    concierge_session = await session_service.create_session(
        app_name=trip_data_concierge_agent.name,
        user_id=my_user_id
    )

    # This query is specifically designed to trigger the full two-step process:
    # 1. Get data from the db_agent.
    # 2. Get a recommendation from the concierge_agent based on that data.
    query = "Find the top-rated hotels in San Francisco from the database, then suggest a dinner spot near the one with the most reviews."
    print(f"🗣️ User Query: '{query}'")

    # We call our existing helper function with the top-level orchestrator agent
    await run_agent_query(trip_data_concierge_agent, query, concierge_session, my_user_id)

# Run the test
await run_trip_data_concierge()
# Out:
# 🗣️ User Query: 'Find the top-rated hotels in San Francisco from the database, then suggest a dinner spot near the one with the most reviews.'
#
# 🚀 Running query for agent: 'trip_data_concierge' in session: '6da924ef-6d6d-4b52-b8a6-98dab89db187'...
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'question': 'top-rated hotels in San Francisco'
#         },
#         id='adk-7178ac29-5bce-4668-abcb-e4d93c48acd5',
#         name='call_db_agent'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=23,
#   prompt_token_count=294,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=294
#     ),
#   ],
#   thoughts_token_count=99,
#   total_token_count=416
# ) invocation_id='e-f355255c-f601-42db-a79c-e27edba95c86' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=set() branch=None id='a2be6a96-3ac4-480b-963d-feda9d49fdd5' timestamp=1753979645.75664
# --- TOOL CALL: call_db_agent ---
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-7178ac29-5bce-4668-abcb-e4d93c48acd5',
#         name='call_db_agent',
#         response={
#           'result': """```json
# {"status": "success", "data": [{"name": "The Grand Hotel", "rating": 5, "reviews": 450}, {"name": "Seaside Inn", "rating": 4, "reviews": 620}]}
# ```"""
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None invocation_id='e-f355255c-f601-42db-a79c-e27edba95c86' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={'retrieved_data': '```json\n{"status": "success", "data": [{"name": "The Grand Hotel", "rating": 5, "reviews": 450}, {"name": "Seaside Inn", "rating": 4, "reviews": 620}]}\n```'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='e35a200e-9ed5-4074-a7ce-812eda05b4a6' timestamp=1753979648.289412
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'question': 'Suggest a dinner spot near Seaside Inn in San Francisco.'
#         },
#         id='adk-ebfc5428-2b55-4881-9c69-f489e4e79b50',
#         name='call_concierge_agent'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=27,
#   prompt_token_count=394,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=394
#     ),
#   ],
#   thoughts_token_count=194,
#   total_token_count=615
# ) invocation_id='e-f355255c-f601-42db-a79c-e27edba95c86' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=set() branch=None id='5e7b8160-8083-434f-af26-a36f83bde431' timestamp=1753979648.294054
# --- TOOL CALL: call_concierge_agent ---
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-ebfc5428-2b55-4881-9c69-f489e4e79b50',
#         name='call_concierge_agent',
#         response={
#           'result': 'Certainly, for an excellent dinner experience near the Seaside Inn, I would highly recommend **The House of Prime Rib**. It offers a truly civilized and satisfying dining experience.'
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None invocation_id='e-f355255c-f601-42db-a79c-e27edba95c86' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='7c29eee3-a7ae-4d71-86cf-4a0977d327ed' timestamp=1753979658.797587
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='Certainly, for an excellent dinner experience near the Seaside Inn, I would highly recommend **The House of Prime Rib**. It offers a truly civilized and satisfying dining experience.'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=33,
#   prompt_token_count=471,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=471
#     ),
#   ],
#   total_token_count=504
# ) invocation_id='e-f355255c-f601-42db-a79c-e27edba95c86' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='650f38e6-2ff3-48a1-8bdb-01d4cdf16877' timestamp=1753979658.802932
#
# --------------------------------------------------
# ✅ Final Response:
# Certainly, for an excellent dinner experience near the Seaside Inn, I would highly recommend **The House of Prime Rib**. It offers a truly civilized and satisfying dining experience.
# --------------------------------------------------

# %% [markdown]
# ---
# ### Final Step: Updating the Router and Running the App
#
# Now we just have one last thing to do: make our `router_agent` aware of these powerful new workflows! We'll add `iterative_planner_agent` and `parallel_planner_agent` to its list of available options.
#
# Then we can run our app with new queries designed to trigger these advanced, multi-agent workflows.

# %% [markdown]
# ```
#                     +---------------------+
#                     |    User Query 🗣️     |
#                     +----------+----------+
#                                |
#                                v
#                     +---------------------+
#                     |   Router Agent 🤖    |
#                     |  (Classify Request) |
#                     +----------+----------+
#                                |
#       +-----------+-----------+-----------+-----------+------------+
#       |           |           |           |           |            |
#       v           v           v           v           v            v
# +-------------+  +------------------+  +------------------+  +------------------+  +-----------------+
# | foodie_agent|  | find_and_navigate|  | iterative_planner|  | parallel_planner |  | day_trip_agent  |
# | 🍣 Food Only |  | 🧭 Seq Workflow   |  | 🔁 Loop Workflow  |  | ⚡ Parallel Tasks |  | 🧳 Basic Plan     |
# +-------------+  +------------------+  +------------------+  +------------------+  +-----------------+
# ```

# %%
# --- The ULTIMATE Router Agent --- #
from google.adk.agents import LlmAgent

router_agent = Agent(
    name="router_agent",
    model="gemini-2.5-flash",
    instruction="""
    You are a master request router. Your job is to analyze a user's query and decide which of the following agents or workflows is best suited to handle it.
    Do not answer the query yourself, only return the name of the most appropriate choice.

    Available Options:
    - 'foodie_agent': For queries *only* about finding a single food place.
    - 'find_and_navigate_agent': For queries that ask to *first find a place* and *then get directions* to it.
    - 'iterative_planner_agent': For planning a trip with a specific constraint that needs checking, like travel time.
    - 'parallel_planner_agent': For queries that ask to find multiple, independent things at once (e.g., a museum AND a concert AND a restaurant).

    Only return the single, most appropriate option's name and nothing else.
    """
)

# The master dictionary of all our executable agents and workflows
worker_agents = {
    "foodie_agent": foodie_agent, # For simple food queries
    "find_and_navigate_agent": find_and_navigate_agent, # Sequential
    "iterative_planner_agent": iterative_planner_agent, # Loop
    "parallel_planner_agent": parallel_planner_agent,   # Parallel
}

# --- Let's Test Everything! ---

async def run_fully_loaded_app():
    queries = [
        # Test Case 1: Simple Sequential Flow
        "Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station.",

        # Test Case 2: Iterative Loop Flow
        "Plan me a day in San Francisco with a museum and a nice dinner, but make sure the travel time between them is very short.",

        # Test Case 3: Parallel Flow
        "Help me plan a trip to SF. I need one museum, one concert, and one great restaurant."
    ]

    for query in queries:
        print(f"\n{'='*60}\n🗣️ Processing New Query: '{query}'\n{'='*60}")

        # 1. Ask the Router Agent to choose the right agent or workflow
        router_session = await session_service.create_session(app_name=router_agent.name, user_id=my_user_id)
        print("🧠 Asking the router agent to make a decision...")
        chosen_route = await run_agent_query(router_agent, query, router_session, my_user_id, is_router=True)
        chosen_route = chosen_route.strip().replace("'", "")
        print(f"🚦 Router has selected route: '{chosen_route}'")

        # 2. Execute the chosen route
        if chosen_route in worker_agents:
            worker_agent = worker_agents[chosen_route]
            print(f"--- Handing off to {worker_agent.name} ---")
            worker_session = await session_service.create_session(app_name=worker_agent.name, user_id=my_user_id)
            await run_agent_query(worker_agent, query, worker_session, my_user_id)
            print(f"--- {worker_agent.name} Complete ---")
        else:
            print(f"🚨 Error: Router chose an unknown route: '{chosen_route}'")

await run_fully_loaded_app()
# Out:
# ============================================================
# 🗣️ Processing New Query: 'Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '260e95a2-2d4f-453a-ad5b-a94a010f5b84'...
# 🚦 Router has selected route: 'find_and_navigate_agent'
# --- Handing off to find_and_navigate_agent ---
#
# 🚀 Running query for agent: 'find_and_navigate_agent' in session: 'c70e42ad-5096-46c9-8d32-c29ccf641a43'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Jin Sho is a highly-rated sushi restaurant in Palo Alto, known for its fresh fish and excellent quality, with many reviews praising their otoro and uni as "buttery and soft" and "creamy and sweet" respectively. It's also notable for being a favorite of Steve Jobs.
#
# To get to Jin Sho from the Caltrain station in Palo Alto:
# 1. Exit the Caltrain station and head southeast on University Avenue toward Alma Street.
# 2. Turn right onto Alma Street.
# 3. Turn left onto California Avenue. Jin Sho will be on your right at 432 California Ave.
#
# The walk is approximately 15-20 minutes, or a short taxi/rideshare."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='stanforddaily.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEuaIKPcpxEXdv6aaHib4Q3sdBb0IrtJRSPMYjKvIg_bHmgAMTuK3QSclgH7l3-g2r0PjC8w4uGg0eZa4zsoYgN_oNcAIHahNPvRIFdTXsUb3tP8kEN_MZutlBorRPPKe3JsRd7wdrQycuU3IsWYhxrPZclKTYjTXH_k49MFJoVxs2o31Mx'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='wanderlog.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEU75WvFymu_3Be_DQWQEmydpDJLE-GytssZfGBtUcYsk29AMRhAjeNhnzL8u8mP08jPyKdAR-X5F89CdwJiAxGRODS3hgmFNda7GmR4OIc8j8lsyVVIygtbngek8YXxAWAvKce63c52hrHSVxfiRUYPY7kce3LqnVHHhXOqRYWimHBaiRvAVRX27XsJB_aLltp2NEkbMh9NQMXuA=='
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=209,
#         text='Jin Sho is a highly-rated sushi restaurant in Palo Alto, known for its fresh fish and excellent quality, with many reviews praising their otoro and uni as "buttery and soft" and "creamy and sweet" respectively'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=263,
#         start_index=211,
#         text="It's also notable for being a favorite of Steve Jobs"
#       )
#     ),
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFojpnBYfj5pD2tMi8OVC8EN4OT14WPhJYTM0UyI4VFxeWHL4IuqgB9ioXChUYcwxT16i9iFoees7qQts13375d6W2aAjhKPygmkV2MGWzUPkvXeAE78QPeO011qyEHTcGswtOGUeKLkLn3Dnzd3tPKoaRRO-bJHtKBYa9tF7gZji8oMQSQSid2e4SwaiL6JhSwLHekQtyWZLbFXa9xcOirh2Oq41F63Va6uQ==">top sushi restaurants Palo Alto reviews</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEz9I5KCNCREGuMs7FFghR-Q3n5UaU94iXZzYKXehE9Y58pziu6rmbw7jgK9lx-fK1DE_sT0ZuetVOhLs7OyygMWpfMa7THnvZm8q5ppEPYitjK2HbjHiE7btUz0ldkir4vlN97c5w-VAV0hkXd3phCK_9Gy1MV2PEQZ-VM4sXjo2fLB0kQs0Nm1F-kPe6pw2cljcCJ-kqW">best sushi Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH3MdCb_qikr9B0uVIR50mETObzVb5JsRqiKCwK5q2g3dJj95WFoOM_VFjFcZd2GYmIVmmmSKMT5bOVKk-ZHFj8CgY5LnRabsNg20EtZjDHTc-miKLjtsTyRV8FSeUEGTWluYuUxaN5uYFn__c9ty_3sCuDxrkIlDiWL_I0sAH8_Lj-9JvbRqBV3OS614AvgEYQY6Dj-GsMR8vO0yiAgSrH">highest rated sushi Palo Alto</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi Palo Alto',
#     'highest rated sushi Palo Alto',
#     'top sushi restaurants Palo Alto reviews',
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=177,
#   prompt_token_count=110,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=110
#     ),
#   ],
#   thoughts_token_count=86,
#   total_token_count=373
# ) invocation_id='e-2f84292d-5f10-4ba3-bbbf-2c29be85ac32' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={'destination': 'Jin Sho is a highly-rated sushi restaurant in Palo Alto, known for its fresh fish and excellent quality, with many reviews praising their otoro and uni as "buttery and soft" and "creamy and sweet" respectively. It\'s also notable for being a favorite of Steve Jobs.\n\nTo get to Jin Sho from the Caltrain station in Palo Alto:\n1. Exit the Caltrain station and head southeast on University Avenue toward Alma Street.\n2. Turn right onto Alma Street.\n3. Turn left onto California Avenue. Jin Sho will be on your right at 432 California Ave.\n\nThe walk is approximately 15-20 minutes, or a short taxi/rideshare.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='ff9c6455-a8ed-4905-a44e-8bef7d7df552' timestamp=1753979674.843208
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""To get to Jin Sho, a highly-rated sushi restaurant in Palo Alto and a favorite of Steve Jobs, from the Caltrain station in Palo Alto, follow these directions:
#
# 1.  Exit the Caltrain station and head southeast on University Avenue toward Alma Street.
# 2.  Turn right onto Alma Street.
# 3.  Turn left onto California Avenue. Jin Sho will be on your right at 432 California Ave.
#
# The walk is approximately 15-20 minutes, or you can opt for a short taxi/rideshare."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata() partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=114,
#   prompt_token_count=546,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=546
#     ),
#   ],
#   thoughts_token_count=87,
#   total_token_count=747
# ) invocation_id='e-2f84292d-5f10-4ba3-bbbf-2c29be85ac32' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='1fc5892a-d97e-4113-87c9-05ce5b23489f' timestamp=1753979684.97358
#
# --------------------------------------------------
# ✅ Final Response:
# To get to Jin Sho, a highly-rated sushi restaurant in Palo Alto and a favorite of Steve Jobs, from the Caltrain station in Palo Alto, follow these directions:
#
# 1.  Exit the Caltrain station and head southeast on University Avenue toward Alma Street.
# 2.  Turn right onto Alma Street.
# 3.  Turn left onto California Avenue. Jin Sho will be on your right at 432 California Ave.
#
# The walk is approximately 15-20 minutes, or you can opt for a short taxi/rideshare.
# --------------------------------------------------
#
# --- find_and_navigate_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Plan me a day in San Francisco with a museum and a nice dinner, but make sure the travel time between them is very short.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '84d3f1d6-3e2f-4fc2-8c43-4e6a0aa110bf'...
# 🚦 Router has selected route: 'iterative_planner_agent'
# --- Handing off to iterative_planner_agent ---
#
# 🚀 Running query for agent: 'iterative_planner_agent' in session: '4dbf8e38-4291-4381-8846-2c8ca40df176'...
#
# --------------------------------------------------
# ✅ Final Response:
# An error occurred: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '10'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
# --------------------------------------------------
#
# --- iterative_planner_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Help me plan a trip to SF. I need one museum, one concert, and one great restaurant.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '0347e254-9265-4fb0-8e9f-84359791fa16'...
# 🚦 Router has selected route: 'An error occurred: 429 RESOURCE_EXHAUSTED. {error: {code: 429, message: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits., status: RESOURCE_EXHAUSTED, details: [{@type: type.googleapis.com/google.rpc.QuotaFailure, violations: [{quotaMetric: generativelanguage.googleapis.com/generate_content_free_tier_requests, quotaId: GenerateRequestsPerMinutePerProjectPerModel-FreeTier, quotaDimensions: {location: global, model: gemini-2.5-flash}, quotaValue: 10}]}, {@type: type.googleapis.com/google.rpc.Help, links: [{description: Learn more about Gemini API quotas, url: https://ai.google.dev/gemini-api/docs/rate-limits}]}, {@type: type.googleapis.com/google.rpc.RetryInfo, retryDelay: 10s}]}}'
# 🚨 Error: Router chose an unknown route: 'An error occurred: 429 RESOURCE_EXHAUSTED. {error: {code: 429, message: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits., status: RESOURCE_EXHAUSTED, details: [{@type: type.googleapis.com/google.rpc.QuotaFailure, violations: [{quotaMetric: generativelanguage.googleapis.com/generate_content_free_tier_requests, quotaId: GenerateRequestsPerMinutePerProjectPerModel-FreeTier, quotaDimensions: {location: global, model: gemini-2.5-flash}, quotaValue: 10}]}, {@type: type.googleapis.com/google.rpc.Help, links: [{description: Learn more about Gemini API quotas, url: https://ai.google.dev/gemini-api/docs/rate-limits}]}, {@type: type.googleapis.com/google.rpc.RetryInfo, retryDelay: 10s}]}}'

# %%
from google.adk.agents import LlmAgent

billing_agent = LlmAgent(name="Billing", description="Handles billing inquiries.")
support_agent = LlmAgent(name="Support", description="Handles technical support requests.")

coordinator = LlmAgent(
    name="HelpDeskCoordinator",
    model="gemini-2.0-flash",
    instruction="Route user requests: Use Billing agent for payment issues, Support agent for technical problems.",
    description="Main help desk router.",
    # allow_transfer=True is often implicit with sub_agents in AutoFlow
    sub_agents=[billing_agent, support_agent]
)

# %%
async def run_coordinator_app():
    queries = [
        "Help me with a billing issue.",
        "Help me with a technical issue."
    ]

    for query in queries:
        # Create a new, single-use session for this query
        coordinator_session = await session_service.create_session(
            app_name=coordinator.name,
            user_id=my_user_id
        )

        print(f"\n{'='*60}\n🗣️ Processing New Query: '{query}'\n{'='*60}")

        # Run the query using the top-level coordinator agent
        await run_agent_query(coordinator, query, coordinator_session, my_user_id)

# Make sure you're inside an async context, or run with asyncio
await run_coordinator_app()
# Out:
# ============================================================
# 🗣️ Processing New Query: 'Help me with a billing issue.'
# ============================================================
#
# 🚀 Running query for agent: 'HelpDeskCoordinator' in session: 'c499a9dd-2bde-4aad-af1c-db3482f97ff2'...
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'agent_name': 'Billing'
#         },
#         id='adk-9eff202c-d1ce-4c00-b4f3-edf5feb0b6a0',
#         name='transfer_to_agent'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=9,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=9
#     ),
#   ],
#   prompt_token_count=233,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=233
#     ),
#   ],
#   total_token_count=242
# ) invocation_id='e-0d7e747e-bc5c-4ca7-aa19-15dd1ea47fb7' author='HelpDeskCoordinator' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=set() branch=None id='a6b4eca5-0c2d-4077-bbe0-0cfdc65f75de' timestamp=1753979819.983529
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-9eff202c-d1ce-4c00-b4f3-edf5feb0b6a0',
#         name='transfer_to_agent',
#         response={
#           'result': None
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None invocation_id='e-0d7e747e-bc5c-4ca7-aa19-15dd1ea47fb7' author='HelpDeskCoordinator' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent='Billing', escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='8947f1c3-8e0b-42f7-a5cf-f61b563c5ea1' timestamp=1753979820.948155
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""How can I help you with your billing issue?
# """
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=11,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=11
#     ),
#   ],
#   prompt_token_count=302,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=302
#     ),
#   ],
#   total_token_count=313
# ) invocation_id='e-0d7e747e-bc5c-4ca7-aa19-15dd1ea47fb7' author='Billing' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='fc10cb02-7680-46e3-9692-a1f4b97e8976' timestamp=1753979820.94925
#
# --------------------------------------------------
# ✅ Final Response:
# How can I help you with your billing issue?
# --------------------------------------------------
#
#
# ============================================================
# 🗣️ Processing New Query: 'Help me with a technical issue.'
# ============================================================
#
# 🚀 Running query for agent: 'HelpDeskCoordinator' in session: 'b811360b-8a17-4de4-8210-3630977a1a1c'...
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'agent_name': 'Support'
#         },
#         id='adk-6b41f33a-1c07-4978-9bfb-6ad6bd6ff4b1',
#         name='transfer_to_agent'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=9,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=9
#     ),
#   ],
#   prompt_token_count=233,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=233
#     ),
#   ],
#   total_token_count=242
# ) invocation_id='e-2e273241-f377-477b-a020-a550d9665872' author='HelpDeskCoordinator' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=set() branch=None id='269b24cc-84b6-4eba-9004-097688cc604a' timestamp=1753979821.522172
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-6b41f33a-1c07-4978-9bfb-6ad6bd6ff4b1',
#         name='transfer_to_agent',
#         response={
#           'result': None
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None invocation_id='e-2e273241-f377-477b-a020-a550d9665872' author='HelpDeskCoordinator' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent='Support', escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='0ecdf2a9-ec95-4011-8a45-cf57d94b8e95' timestamp=1753979822.289226
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""How can I assist you with your technical issue? Please provide more details about the problem you are experiencing.
# """
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=22,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=22
#     ),
#   ],
#   prompt_token_count=302,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=302
#     ),
#   ],
#   total_token_count=324
# ) invocation_id='e-2e273241-f377-477b-a020-a550d9665872' author='Support' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='bfc79c53-45f6-4c1d-b670-8dfcf14edead' timestamp=1753979822.290311
#
# --------------------------------------------------
# ✅ Final Response:
# How can I assist you with your technical issue? Please provide more details about the problem you are experiencing.
# --------------------------------------------------

# %% [markdown]
# ###Iterative Refinement Pattern

# %%
# --- A Tool to Exit the Loop ---
# This special phrase tells our Refiner agent that the job is done.
COMPLETION_PHRASE = "The plan is feasible and meets all constraints."

def exit_loop(tool_context: ToolContext):
  """Call this function ONLY when the plan is approved and the loop should end."""
  print(f"  [Tool Call] exit_loop triggered. The plan is good!")
  # Setting escalate=True tells the LoopAgent to stop iterating.
  tool_context.actions.escalate = True
  return {"status": "Loop terminated successfully."}

# --- Agent 1: The Initial Planner ---
# This agent runs ONCE to create the first draft of the plan.
planner_agent = Agent(
    name="planner_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are a creative trip planner. Based on the user's request, propose a single, interesting activity and a single, well-known restaurant. Output only the names, like: 'Activity: Exploratorium, Restaurant: La Mar'.",
    # The output is saved to the shared state for the other agents to use.
    output_key="current_plan"
)

# --- Agent 2: The Loop Critic ---
# This agent's job is to check the work and provide feedback.
critic_agent = Agent(
    name="critic_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction=f"""You are a logistics expert with a map. Your job is to critique a travel plan based on a strict constraint.
    The user's constraint is that the travel time between the two locations must be short.

    Current Plan: {{current_plan}}

    Use your tools to check the driving time between the two locations.
    - IF the travel time is 20 minutes or less, you MUST respond with the exact phrase: '{COMPLETION_PHRASE}'
    - IF the travel time is OVER 20 minutes, provide a specific critique, like: 'This plan is inefficient. Find a restaurant closer to the activity.'
    - IF YOU CANNOT DETERMINE the travel time for any reason, you MUST respond with: 'Unable to verify travel time for the current plan.'
    """,
    # The critique is saved to the state for the Refiner agent.
    output_key="criticism"
)

# --- Agent 3: The Loop Refiner ---
# This agent's job is to read the critique and fix the plan.
refiner_agent = Agent(
    name="refiner_agent",
    model="gemini-2.5-flash",
    tools=[exit_loop],
    instruction=f"""You are a problem-solving trip planner, refining a plan based on criticism.

    Original Request: {{session.query}}
    The Plan to Fix: {{current_plan}}
    The Criticism to Address: {{criticism}}

    - IF the critique is '{COMPLETION_PHRASE}', your job is done. You MUST call the 'exit_loop' tool and do nothing else.
    - ELSE, generate a NEW plan that directly addresses the critique. Find a new location to replace the inefficient one. Output only the new plan names, like: 'Activity: de Young Museum, Restaurant: Nopa'.""",
    # The refined plan OVERWRITES the old plan in the state.
    output_key="current_plan"
)

print("✅ Iteration team is assembled: Planner, Critic, and Refiner.")
# Out:
# ✅ Iteration team is assembled: Planner, Critic, and Refiner.

# %%
# The LoopAgent orchestrates the critique -> refine cycle.
refinement_loop = LoopAgent(
    name="refinement_loop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=4 # A safety net to prevent infinite loops
)

# The SequentialAgent puts it all together: Plan first, then loop.
iterative_planner_agent = SequentialAgent(
    name="iterative_planner_agent",
    sub_agents=[planner_agent, refinement_loop],
    description="A workflow that iteratively plaans and refines a trip to meet constraints."
)

print(f"🤖 Iterative workflow '{iterative_planner_agent.name}' is online!")
# Out:
# 🤖 Iterative workflow 'iterative_planner_agent' is online!

# %%
async def run_iterative_test():
    """Sets up a session and runs a query against the iterative planner."""

    # This query is designed to fail the first check.
    # The California Academy of Sciences and Fisherman's Wharf are far apart.
    query = "I want to plan a day in San Francisco. I'd like to visit the California Academy of Sciences and then eat dinner at a famous restaurant at Fisherman's Wharf. My only rule is the drive between them must be under 20 minutes."

    print(f"🗣️ User Query: '{query}'")

    # 1. Create a new, single-use session for this entire job.
    iterative_session = await session_service.create_session(
        app_name=iterative_planner_agent.name,
        user_id=my_user_id
    )

    # 2. Call our helper function with the agent, query, and the new session.
    await run_agent_query(
        agent=iterative_planner_agent,
        query=query,
        session=iterative_session,
        user_id=my_user_id
    )

# Run the test
await run_iterative_test()
# Out:
# 🗣️ User Query: 'I want to plan a day in San Francisco. I'd like to visit the California Academy of Sciences and then eat dinner at a famous restaurant at Fisherman's Wharf. My only rule is the drive between them must be under 20 minutes.'
#
# 🚀 Running query for agent: 'iterative_planner_agent' in session: 'f924431b-bd62-4fd4-901f-da4a1ab07d5a'...
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Activity: California Academy of Sciences
# Restaurant: Scoma's"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGrn_yOi-fFV02PI7brdUXOcd0TQffRv2yAzfdrHb9OHi1n-ON_Tg_00RBbhBtlEZjiHhFgPcFQ4s4m6Uj_pTFjOKKPR6kwBrlCS0HJb4DpivB7IjqwHLelN9m5PVPBBXl4sbCs_R0O1gPfATjrVQHJLqHdRyWqaVuQ4iVskO_NIu5EqBNiLy-R_86ktgjPpDLa-4mUYIBxJIGDdYH9nAz6-T75qQg_hSvKkoRd7iuWjgc4tdGEwiU=">famous restaurants Fisherman&#39;s Wharf San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEf_wwz54j-LfCIdUQZ_z2vuW9RboRDDRml-x19fx3wnUDa6TxX8zdSFCG7zOj5j4xh7_RSyUvAa58PbmtQky10zeQNan2mI_65mm8yY9R4ZB04rERxZMTNlc4OCak29-mkZEjD1KxQ07Kfku8HCCUDWbrG_dkl9Sr3rafUo25tBya2i5pLEdCX458tdTL-0IZya-Rxs0gxdXKvpz-p6KKYhovqUiACLLMPKOPZIkLAhRzD_-6taxX8c9600rpybnw3k0nZjg==">driving time California Academy of Sciences to Fisherman&#39;s Wharf</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     "driving time California Academy of Sciences to Fisherman's Wharf",
#     "famous restaurants Fisherman's Wharf San Francisco",
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=45,
#   prompt_token_count=116,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=116
#     ),
#   ],
#   thoughts_token_count=544,
#   total_token_count=705
# ) invocation_id='e-7f6e223f-a792-4d4d-9f00-9bda0d0e6fcd' author='planner_agent' actions=EventActions(skip_summarization=None, state_delta={'current_plan': "Activity: California Academy of Sciences\nRestaurant: Scoma's"}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='c01889d8-0c37-4cdb-ae71-d33176238792' timestamp=1753979847.586084
# EVENT: content=Content(
#   parts=[
#     Part(
#       text='The plan is feasible and meets all constraints.'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFzjbH1ritxHnP_iKa_wkefXQC0el57sfr-fQsrV4GulDitMGkcrJfDX_oVTd7yA2VdvWPsY7Dhyee5i0c4WXSazS8dslnknbBbvRSigYNGA-qm4EhT8oyDQSpSV0C736UIddffjuXXaSQtFc6vZlq9oOH5b34E_Nf0MLYFkHjihMOOGIJnglMhYVilFBWesChnMIInzfbtIoUrk5yiCgmomyg_hko59zQ7ggj3eMqT20v-5jQual12eBxrkOJZizkxqWccG9XdYGgUJ5cCUUs41Z_b_lqkMqeoXdMBsA==">driving time California Academy of Sciences to Scoma&#39;s Fisherman&#39;s Wharf San Francisco</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     "driving time California Academy of Sciences to Scoma's San Francisco",
#     "driving time California Academy of Sciences to Scoma's Fisherman's Wharf San Francisco",
#   ]
# ) partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=61,
#   prompt_token_count=270,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=270
#     ),
#   ],
#   thoughts_token_count=303,
#   total_token_count=634
# ) invocation_id='e-7f6e223f-a792-4d4d-9f00-9bda0d0e6fcd' author='critic_agent' actions=EventActions(skip_summarization=None, state_delta={'criticism': 'The plan is feasible and meets all constraints.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='debaf9c7-8aae-47d7-8f68-ec12a575ee35' timestamp=1753979857.988955
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={},
#         id='adk-2994311f-181e-460f-ba7c-be35812126fc',
#         name='exit_loop'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=10,
#   prompt_token_count=294,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=294
#     ),
#   ],
#   thoughts_token_count=125,
#   total_token_count=429
# ) invocation_id='e-7f6e223f-a792-4d4d-9f00-9bda0d0e6fcd' author='refiner_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=set() branch=None id='895a9255-7c4d-491f-b109-8c0bbca2ccf5' timestamp=1753979868.423503
#   [Tool Call] exit_loop triggered. The plan is good!
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-2994311f-181e-460f-ba7c-be35812126fc',
#         name='exit_loop',
#         response={
#           'status': 'Loop terminated successfully.'
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None invocation_id='e-7f6e223f-a792-4d4d-9f00-9bda0d0e6fcd' author='refiner_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=True, requested_auth_configs={}) long_running_tool_ids=None branch=None id='93a80b92-0736-4aae-bb81-a3f0c5785c5e' timestamp=1753979869.704192
#
# --------------------------------------------------
# ✅ Final Response:
# An error occurred: 500 INTERNAL. {'error': {'code': 500, 'message': 'An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting', 'status': 'INTERNAL'}}
# --------------------------------------------------

# %% [markdown]
# ##Human-in-the-Loop Pattern

# %%
def request_human_approval(amount: float, reason: str) -> dict:
    """
    Pauses the workflow and asks for human approval for an expense.
    This tool simulates a human-in-the-loop interaction by using input().
    """
    print("\n" + "="*60)
    print("🚨 HUMAN ACTION REQUIRED 🚨")
    print(f"An agent is requesting approval for an expense.")
    print(f"  - Amount: ${amount:,.2f}")
    print(f"  - Reason: {reason}")
    print("="*60)

    # Loop until valid input is received
    while True:
        # The input() function pauses execution here!
        decision = input("Please type 'yes' to approve or 'no' to deny: ").lower().strip()
        if decision in ["yes", "no"]:
            print(f"✅ Human has decided: '{decision}'. Resuming workflow...")
            return {"human_decision": decision}
        else:
            print("Invalid input. Please enter 'yes' or 'no'.")

print("🛠️ Human interaction tool is defined.")
# Out:
# 🛠️ Human interaction tool is defined.

# %%
# --- Define a clearly-typed function to be used as a tool ---
def save_expense_details(amount: float, reason: str, tool_context: ToolContext):
    """Saves the extracted expense details to the session state."""
    print(f"🛠️ TOOL CALLED: save_expense_details(amount={amount}, reason='{reason}')")
    tool_context.state.update({
        "expense_amount": amount,
        "expense_reason": reason
    })
    return {"status": "success", "message": f"Saved amount: {amount}, reason: {reason}"}


# --- Agent 1: The Expense Preparer ---
# This agent's only job is to parse the user's request and get the data ready.
expense_preparer_agent = Agent(
    name="expense_preparer_agent",
    model="gemini-2.5-flash",
    instruction="""You are an expense report assistant. From the user's plain-text request, extract the dollar amount and the reason for the expense.
    The 'amount' should be a number, ignoring any currency symbols like '$'.
    You MUST call the `save_expense_details` tool with these details.""",
    tools=[save_expense_details],
)


# --- Agent 2: The Approval Requester ---
# This agent's only job is to call the tool that pauses for human input.
approval_requester_agent = Agent(
    name="approval_requester_agent",
    model="gemini-2.5-flash",
    instruction="Your job is to request human approval for the expense. You MUST use the `request_human_approval` tool, passing it the `expense_amount` and `expense_reason` from the session state.",
    tools=[request_human_approval],
    # Save the human's response to the state for the next agent
    output_key="human_decision"
)


# --- Agent 3: The Decision Processor ---
# This agent acts on the human's final decision.
decision_processor_agent = Agent(
    name="decision_processor_agent",
    model="gemini-2.5-flash",
    instruction="You are the final step in the expense process. Read the `{human_decision}` from the state. If the decision was 'yes', respond to the user that their expense report has been approved and submitted. If it was 'no', inform them that the expense report was denied by the manager.",
)


print("✅ Agent team for expense approval is ready.")
# Out:
# ✅ Agent team for expense approval is ready.

# %%
# The SequentialAgent ensures our agents run in the correct order.
human_approval_workflow = SequentialAgent(
    name="human_approval_workflow",
    sub_agents=[
        expense_preparer_agent,
        approval_requester_agent,
        decision_processor_agent
    ],
    description="A workflow that prepares an expense report and requires human approval before finalizing."
)

print(f"🤖 Workflow '{human_approval_workflow.name}' is online.")

# --- Let's run the test! ---
async def run_human_in_loop_test():
    """Sets up a session and runs a query that requires human intervention."""

    query = "Hi there, I need to file an expense report for my flight to the Next '25 conference in Las Vegas. The total cost was $782.55."
    print(f"🗣️ User Query: '{query}'")

    # Create a session for this specific job
    approval_session = await session_service.create_session(
        app_name=human_approval_workflow.name,
        user_id=my_user_id
    )

    # Call our helper function. It will pause mid-execution!
    await run_agent_query(
        agent=human_approval_workflow,
        query=query,
        session=approval_session,
        user_id=my_user_id
    )

# When you run this cell, be ready to type "yes" or "no" into the input box!
await run_human_in_loop_test()
# Out:
# 🤖 Workflow 'human_approval_workflow' is online.
# 🗣️ User Query: 'Hi there, I need to file an expense report for my flight to the Next '25 conference in Las Vegas. The total cost was $782.55.'
#
# 🚀 Running query for agent: 'human_approval_workflow' in session: 'b17c5791-efd2-4cf1-9e4b-e1a9d6f76d09'...
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'amount': 782.55,
#           'reason': "Flight to the Next '25 conference in Las Vegas"
#         },
#         id='adk-d81c59b9-d616-46dd-ae4b-870b6d0b3bfe',
#         name='save_expense_details'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=37,
#   prompt_token_count=177,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=177
#     ),
#   ],
#   thoughts_token_count=87,
#   total_token_count=301
# ) invocation_id='e-fb368dc8-a280-4f6a-9982-5e147861c5ce' author='expense_preparer_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=set() branch=None id='019944da-b46c-45f5-9f0d-4b4b3cba4e42' timestamp=1753979883.361261
# 🛠️ TOOL CALLED: save_expense_details(amount=782.55, reason='Flight to the Next '25 conference in Las Vegas')
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-d81c59b9-d616-46dd-ae4b-870b6d0b3bfe',
#         name='save_expense_details',
#         response={
#           'message': "Saved amount: 782.55, reason: Flight to the Next '25 conference in Las Vegas",
#           'status': 'success'
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None invocation_id='e-fb368dc8-a280-4f6a-9982-5e147861c5ce' author='expense_preparer_agent' actions=EventActions(skip_summarization=None, state_delta={'expense_amount': 782.55, 'expense_reason': "Flight to the Next '25 conference in Las Vegas"}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='60651582-7e64-4515-a8ba-74e14d94bf3f' timestamp=1753979884.549465
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="""Got it! I've saved your expense of $782.55 for your flight to the Next '25 conference in Las Vegas.
# """
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=31,
#   prompt_token_count=260,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=260
#     ),
#   ],
#   total_token_count=291
# ) invocation_id='e-fb368dc8-a280-4f6a-9982-5e147861c5ce' author='expense_preparer_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='74408bd9-56b3-45ec-bdd2-d3301639f74e' timestamp=1753979884.553578
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'amount': 782.55,
#           'reason': "Flight to the Next '25 conference in Las Vegas"
#         },
#         id='adk-726e3684-e1a9-4d25-ae0a-594f89f31d19',
#         name='request_human_approval'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=37,
#   prompt_token_count=337,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=337
#     ),
#   ],
#   thoughts_token_count=155,
#   total_token_count=529
# ) invocation_id='e-fb368dc8-a280-4f6a-9982-5e147861c5ce' author='approval_requester_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=set() branch=None id='8a723c27-07be-4808-bd7f-55b67361a396' timestamp=1753979885.307426
#
# ============================================================
# 🚨 HUMAN ACTION REQUIRED 🚨
# An agent is requesting approval for an expense.
#   - Amount: $782.55
#   - Reason: Flight to the Next '25 conference in Las Vegas
# ============================================================
# Please type 'yes' to approve or 'no' to deny: yes
# ✅ Human has decided: 'yes'. Resuming workflow...
# EVENT: content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-726e3684-e1a9-4d25-ae0a-594f89f31d19',
#         name='request_human_approval',
#         response={
#           'human_decision': 'yes'
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None invocation_id='e-fb368dc8-a280-4f6a-9982-5e147861c5ce' author='approval_requester_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='c7dbaef2-89e3-4425-b99f-9e5b212dd0f4' timestamp=1753979891.978651
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="The expense for your flight to the Next '25 conference in Las Vegas, totaling $782.55, has been approved."
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=29,
#   prompt_token_count=393,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=393
#     ),
#   ],
#   thoughts_token_count=151,
#   total_token_count=573
# ) invocation_id='e-fb368dc8-a280-4f6a-9982-5e147861c5ce' author='approval_requester_agent' actions=EventActions(skip_summarization=None, state_delta={'human_decision': "The expense for your flight to the Next '25 conference in Las Vegas, totaling $782.55, has been approved."}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='f585f05d-cdab-42ac-80bc-ea804340cb9a' timestamp=1753979891.985127
# EVENT: content=Content(
#   parts=[
#     Part(
#       text="Your expense report for the flight to the Next '25 conference has been approved and submitted."
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=19,
#   prompt_token_count=423,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=423
#     ),
#   ],
#   thoughts_token_count=112,
#   total_token_count=554
# ) invocation_id='e-fb368dc8-a280-4f6a-9982-5e147861c5ce' author='decision_processor_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}) long_running_tool_ids=None branch=None id='846b8ca5-3fe4-468b-9bad-d3c0e2de342d' timestamp=1753979893.503778
#
# --------------------------------------------------
# ✅ Final Response:
# Your expense report for the flight to the Next '25 conference has been approved and submitted.
# --------------------------------------------------
